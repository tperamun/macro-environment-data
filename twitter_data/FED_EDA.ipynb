# %%
import pandas as pd

data = pd.read_pickle('FED_dtm.pkl')
data.head()
# Out:
#                 absolutly  accelerate  accountn  action  address  adjustedfed  \
# BlackOutWhale           1           0         0       0        0            0
# CurrencyGuy             0           0         0       0        0            0
# DennisKelleher          0           0         0       0        0            0
# EconomicsRisk           0           0         0       0        0            0
# FXStreetNews            0           0         0       0        1            0
#
#                 admitted  althou  amp  answer  ...  words  work  world  worry  \
# BlackOutWhale          0       0    0       0  ...      0     0      0      0
# CurrencyGuy            0       0    0       0  ...      0     0      0      0
# DennisKelleher         0       0    0       0  ...      0     0      0      0
# EconomicsRisk          0       0    0       0  ...      0     0      0      0
# FXStreetNews           0       0    0       0  ...      0     0      0      0
#
#                 wreck  xglobalmarkets  xlf  yields  zero  zerocovid
# BlackOutWhale       0               0    0       0     0          0
# CurrencyGuy         0               0    0       0     0          0
# DennisKelleher      0               0    0       0     0          0
# EconomicsRisk       0               0    0       0     0          0
# FXStreetNews        0               0    0       0     0          0
#
# [5 rows x 381 columns]

# %%
data = data.transpose()
data.head()
# Out:
#             BlackOutWhale  CurrencyGuy  DennisKelleher  EconomicsRisk  \
# absolutly               1            0               0              0
# accelerate              0            0               0              0
# accountn                0            0               0              0
# action                  0            0               0              0
# address                 0            0               0              0
#
#             FXStreetNews  Geopolitix3  Go_CIO  GregDaco  HakimiMahalil  \
# absolutly              0            0       0         0              0
# accelerate             0            0       0         0              0
# accountn               0            0       0         0              0
# action                 0            0       0         0              0
# address                1            0       0         0              0
#
#             JEREMYSONG750  ...  sohaibeth  soldatthetop  sumitkapoor16  \
# absolutly               0  ...          0             0              0
# accelerate              0  ...          0             0              0
# accountn                0  ...          0             0              0
# action                  0  ...          0             0              0
# address                 0  ...          0             0              0
#
#             thakre_aarya  themacrotweet  vinniepalma  wallstmaster  x2da4  \
# absolutly              0              0            0             0      0
# accelerate             0              0            0             0      0
# accountn               0              0            0             0      0
# action                 0              0            0             0      0
# address                0              0            0             0      0
#
#             xglobalmarkets  yellowdijon
# absolutly                0            0
# accelerate               0            0
# accountn                 0            0
# action                   0            0
# address                  0            0
#
# [5 rows x 65 columns]

# %%
# find top 30 words said by each account

top_dict = {}

for u in data.columns:
    
    top = data[u].sort_values(ascending=False).head(30)
    top_dict[u] = list(zip(top.index, top.values))

top_dict
# Out:
# {'BlackOutWhale': [('absolutly', 1),
#   ('kennedy', 1),
#   ('cryptocrash', 1),
#   ('grilled', 1),
#   ('powellduh', 1),
#   ('fed', 1),
#   ('points', 0),
#   ('policy', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('pivots', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('plan', 0),
#   ('powellfed', 0),
#   ('process', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('probably', 0),
#   ('public', 0),
#   ('profits', 0),
#   ('really', 0),
#   ('require', 0),
#   ('report', 0)],
#  'CurrencyGuy': [('price', 2),
#   ('stability', 2),
#   ('restore', 1),
#   ('fed', 1),
#   ('bedrock', 1),
#   ('really', 1),
#   ('economy', 1),
#   ('powell', 1),
#   ('powellfed', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('possible', 0),
#   ('powellduh', 0),
#   ('process', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('probably', 0),
#   ('absolutly', 0),
#   ('profits', 0),
#   ('pity', 0)],
#  'DennisKelleher': [('federalreserve', 1),
#   ('chair', 1),
#   ('committee', 1),
#   ('basel', 1),
#   ('capital', 1),
#   ('senatebanking', 1),
#   ('gsib', 1),
#   ('asked', 1),
#   ('european', 1),
#   ('hearing', 1),
#   ('powell', 1),
#   ('lowering', 1),
#   ('pop', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('points', 0),
#   ('policy', 0),
#   ('positive', 0),
#   ('powellduh', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('process', 0),
#   ('possibility', 0),
#   ('possible', 0),
#   ('probably', 0),
#   ('qqq', 0)],
#  'EconomicsRisk': [('consumer', 1),
#   ('rece', 1),
#   ('shattering', 1),
#   ('inflation', 1),
#   ('forecast', 1),
#   ('investor', 1),
#   ('confidence', 1),
#   ('leaning', 1),
#   ('probabilities', 1),
#   ('closer', 1),
#   ('high', 1),
#   ('possibility', 0),
#   ('prices', 0),
#   ('printer', 0),
#   ('points', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('price', 0),
#   ('positive', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('policy', 0),
#   ('possible', 0),
#   ('pop', 0),
#   ('absolutly', 0),
#   ('profits', 0),
#   ('probably', 0),
#   ('reach', 0)],
#  'FXStreetNews': [('powell', 1),
#   ('address', 1),
#   ('fed', 1),
#   ('inflation', 1),
#   ('erenfxstreet', 1),
#   ('centralbanks', 1),
#   ('speech', 1),
#   ('focused', 1),
#   ('powellfed', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('process', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('probably', 0),
#   ('qe', 0),
#   ('profits', 0),
#   ('really', 0)],
#  'Geopolitix3': [('treasury', 1),
#   ('fed', 1),
#   ('stimulus', 1),
#   ('fuel', 1),
#   ('inflation', 1),
#   ('threw', 1),
#   ('powellduh', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('absolutly', 0),
#   ('probabilities', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('powell', 0),
#   ('probably', 0),
#   ('pin', 0),
#   ('reach', 0),
#   ('rep', 0)],
#  'Go_CIO': [('does', 1),
#   ('talking', 1),
#   ('fed', 1),
#   ('gap', 1),
#   ('start', 1),
#   ('skills', 1),
#   ('want', 1),
#   ('powellfed', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('probably', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('powell', 0),
#   ('process', 0),
#   ('pity', 0),
#   ('profits', 0)],
#  'GregDaco': [('causin', 1),
#   ('understand', 1),
#   ('monetary', 1),
#   ('powell', 1),
#   ('hardship', 1),
#   ('inflation', 1),
#   ('congress', 1),
#   ('chair', 1),
#   ('semiannual', 1),
#   ('high', 1),
#   ('fed', 1),
#   ('policy', 1),
#   ('report', 1),
#   ('powellfed', 0),
#   ('primarily', 0),
#   ('prices', 0),
#   ('print', 0),
#   ('price', 0),
#   ('pricesrate', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('probabilities', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('points', 0),
#   ('printer', 0),
#   ('profits', 0),
#   ('probably', 0)],
#  'HakimiMahalil': [('qe', 2),
#   ('march', 1),
#   ('november', 1),
#   ('gameoftrades', 1),
#   ('began', 1),
#   ('qt', 1),
#   ('ended', 1),
#   ('recently', 1),
#   ('nomadrevelation', 1),
#   ('fed', 1),
#   ('tapered', 1),
#   ('possibility', 0),
#   ('positive', 0),
#   ('points', 0),
#   ('probably', 0),
#   ('policy', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('process', 0),
#   ('pop', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('powellduh', 0),
#   ('absolutly', 0)],
#  'JEREMYSONG750': [('shortterm', 1),
#   ('blunttool', 1),
#   ('fed', 1),
#   ('financial', 1),
#   ('influence', 1),
#   ('primarily', 1),
#   ('conditions', 1),
#   ('powellfed', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powell', 0),
#   ('powellduh', 0),
#   ('process', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('probably', 0),
#   ('absolutly', 0),
#   ('pity', 0),
#   ('realizing', 0),
#   ('report', 0)],
#  'JessieLivermore': [('fed', 1),
#   ('worry', 1),
#   ('folks', 1),
#   ('powellduh', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powell', 0),
#   ('profits', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('process', 0),
#   ('public', 0),
#   ('pin', 0),
#   ('qe', 0),
#   ('require', 0),
#   ('report', 0)],
#  'KVanderschrick': [('powell', 1),
#   ('rises', 1),
#   ('wages', 1),
#   ('flattening', 1),
#   ('housingrate', 1),
#   ('evidence', 1),
#   ('theres', 1),
#   ('seeing', 1),
#   ('slowing', 1),
#   ('shoul', 1),
#   ('feds', 1),
#   ('primarily', 0),
#   ('prices', 0),
#   ('print', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('pricesrate', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('probabilities', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('printer', 0),
#   ('public', 0),
#   ('probably', 0)],
#  'KanzenZasi': [('people', 1),
#   ('fall', 1),
#   ('doingfed', 1),
#   ('believe', 1),
#   ('lawyer', 1),
#   ('markets', 1),
#   ('tell', 1),
#   ('doing', 1),
#   ('points', 1),
#   ('yields', 1),
#   ('policy', 0),
#   ('prices', 0),
#   ('pivots', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('price', 0),
#   ('pop', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('process', 0),
#   ('plan', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('possible', 0),
#   ('public', 0)],
#  'KenR0415': [('powell', 1),
#   ('fed', 1),
#   ('bones', 1),
#   ('coughing', 1),
#   ('huh', 1),
#   ('powellfed', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('process', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('probably', 0),
#   ('profits', 0),
#   ('pity', 0),
#   ('really', 0),
#   ('require', 0),
#   ('report', 0)],
#  'KitcoNewsNOW': [('china', 2),
#   ('long', 1),
#   ('ve', 1),
#   ('seen', 1),
#   ('powell', 1),
#   ('policy', 1),
#   ('lockdowns', 1),
#   ('expect', 1),
#   ('effects', 1),
#   ('don', 1),
#   ('zerocovid', 1),
#   ('appropriate', 0),
#   ('price', 0),
#   ('profits', 0),
#   ('process', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('powellfed', 0),
#   ('right', 0),
#   ('powellduh', 0),
#   ('address', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0)],
#  'MBjegovic': [('pivots', 1),
#   ('peak', 1),
#   ('septembereconomy', 1),
#   ('rate', 1),
#   ('july', 1),
#   ('reach', 1),
#   ('cuts', 1),
#   ('expect', 1),
#   ('fed', 1),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('plan', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('points', 0),
#   ('pop', 0),
#   ('price', 0),
#   ('policy', 0),
#   ('process', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('powellfed', 0),
#   ('absolutly', 0),
#   ('profits', 0)],
#  'MoodixMarket': [('sentiment', 2),
#   ('fed', 1),
#   ('positive', 1),
#   ('news', 1),
#   ('today', 1),
#   ('negative', 1),
#   ('week', 1),
#   ('strength', 1),
#   ('longterm', 1),
#   ('points', 0),
#   ('policy', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('pivots', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('plan', 0),
#   ('pop', 0),
#   ('probabilities', 0),
#   ('process', 0),
#   ('probably', 0),
#   ('reach', 0)],
#  'Mrs__finance': [('looking', 1),
#   ('evidence', 1),
#   ('compelling', 1),
#   ('powell', 1),
#   ('inflation', 1),
#   ('moving', 1),
#   ('months', 1),
#   ('said', 1),
#   ('coming', 1),
#   ('fed', 1),
#   ('rep', 1),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('record', 0),
#   ('probabilities', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('require', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('report', 0)],
#  'PSuiteNetwork': [('hikes', 4),
#   ('dont', 3),
#   ('make', 2),
#   ('gas', 1),
#   ('rate', 1),
#   ('pricesrate', 1),
#   ('formularate', 1),
#   ('baby', 1),
#   ('fertilizerrate', 1),
#   ('lower', 1),
#   ('prices', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('probably', 0),
#   ('process', 0),
#   ('primarily', 0),
#   ('probabilities', 0),
#   ('absolutly', 0),
#   ('price', 0),
#   ('profits', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('powellfed', 0),
#   ('qqq', 0)],
#  'PeterSchiff': [('realizing', 1),
#   ('concerned', 1),
#   ('sell', 1),
#   ('assets', 1),
#   ('powell', 1),
#   ('huge', 1),
#   ('balance', 1),
#   ('said', 1),
#   ('cur', 1),
#   ('fed', 1),
#   ('losses', 1),
#   ('sheet', 1),
#   ('print', 0),
#   ('primarily', 0),
#   ('printer', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('probabilities', 0),
#   ('price', 0),
#   ('absolutly', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('process', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('probably', 0)],
#  'PeterSm16087569': [('fed', 2),
#   ('economics', 2),
#   ('senate', 2),
#   ('does', 1),
#   ('history', 1),
#   ('understand', 1),
#   ('obvious', 1),
#   ('hearing', 1),
#   ('inflation', 1),
#   ('today', 1),
#   ('absolutly', 0),
#   ('prices', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('price', 0),
#   ('probabilities', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('printer', 0),
#   ('profits', 0),
#   ('probably', 0)],
#  'RealMMOShow': [('profits', 1),
#   ('companies', 1),
#   ('record', 1),
#   ('making', 1),
#   ('driving', 1),
#   ('oil', 1),
#   ('masto', 1),
#   ('prices', 1),
#   ('cortez', 1),
#   ('price', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('absolutly', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('probably', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('powell', 0),
#   ('public', 0),
#   ('process', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0)],
#  'ReddySalina': [('inflation', 1),
#   ('fed', 1),
#   ('accelerate', 1),
#   ('hikes', 1),
#   ('rate', 1),
#   ('suggested', 1),
#   ('needed', 1),
#   ('powell', 1),
#   ('recent', 1),
#   ('pace', 1),
#   ('indicators', 1),
#   ('price', 0),
#   ('powellfed', 0),
#   ('absolutly', 0),
#   ('prices', 0),
#   ('pricesrate', 0),
#   ('powellduh', 0),
#   ('possibility', 0),
#   ('possible', 0),
#   ('print', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('primarily', 0),
#   ('process', 0),
#   ('printer', 0)],
#  'RosannaTrades': [('fed', 2),
#   ('powell', 1),
#   ('amp', 1),
#   ('rate', 1),
#   ('ongoing', 1),
#   ('tighten', 1),
#   ('needed', 1),
#   ('inflation', 1),
#   ('hot', 1),
#   ('tame', 1),
#   ('admitted', 1),
#   ('slow', 1),
#   ('hikes', 1),
#   ('sees', 1),
#   ('powellfed', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('primarily', 0),
#   ('price', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('printer', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('print', 0)],
#  'Sino_Market': [('thats', 1),
#   ('competiti', 1),
#   ('oil', 1),
#   ('powell', 1),
#   ('industry', 1),
#   ('need', 1),
#   ('headed', 1),
#   ('judgment', 1),
#   ('make', 1),
#   ('policy', 1),
#   ('feds', 1),
#   ('restrictive', 1),
#   ('prices', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('absolutly', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('probably', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('points', 0),
#   ('probabilities', 0),
#   ('profits', 0),
#   ('process', 0)],
#  'SunAndStormInv': [('iwm', 1),
#   ('spx', 1),
#   ('deliberately', 1),
#   ('inflation', 1),
#   ('qqq', 1),
#   ('economy', 1),
#   ('slowing', 1),
#   ('case', 1),
#   ('control', 1),
#   ('ijh', 1),
#   ('fed', 1),
#   ('spy', 1),
#   ('powell', 0),
#   ('print', 0),
#   ('policy', 0),
#   ('primarily', 0),
#   ('pop', 0),
#   ('positive', 0),
#   ('possibility', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('possible', 0),
#   ('probabilities', 0),
#   ('powellduh', 0),
#   ('printer', 0),
#   ('absolutly', 0),
#   ('probably', 0),
#   ('plan', 0)],
#  'TheNobleRetard': [('pivotmarketsequitiesfedfederalreserve', 1),
#   ('smell', 1),
#   ('absolutly', 0),
#   ('powell', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('probably', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pity', 0),
#   ('probabilities', 0),
#   ('process', 0),
#   ('peterschiff', 0),
#   ('realizing', 0),
#   ('report', 0),
#   ('rep', 0),
#   ('refused', 0),
#   ('record', 0)],
#  'UnEspeculador': [('jay', 1),
#   ('zero', 1),
#   ('fed', 1),
#   ('don', 1),
#   ('inflation', 1),
#   ('goes', 1),
#   ('powell', 1),
#   ('prices', 1),
#   ('price', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('powellduh', 0),
#   ('powellfed', 0),
#   ('process', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('probably', 0),
#   ('absolutly', 0),
#   ('profits', 0),
#   ('realizing', 0),
#   ('report', 0)],
#  'UpshotSleuth': [('house', 2),
#   ('federal', 1),
#   ('white', 1),
#   ('require', 1),
#   ('equity', 1),
#   ('endorses', 1),
#   ('racial', 1),
#   ('include', 1),
#   ('mon', 1),
#   ('reserve', 1),
#   ('making', 1),
#   ('markets', 0),
#   ('pricesrate', 0),
#   ('public', 0),
#   ('profits', 0),
#   ('process', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('prices', 0),
#   ('qqq', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0)],
#  'VanessaBrownTV': [('economy', 2),
#   ('plan', 1),
#   ('people', 1),
#   ('powell', 1),
#   ('fix', 1),
#   ('stocks', 1),
#   ('nonexpert', 1),
#   ('wreck', 1),
#   ('lose', 1),
#   ('fed', 1),
#   ('help', 1),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('probably', 0),
#   ('points', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('possibility', 0),
#   ('absolutly', 0),
#   ('process', 0),
#   ('profits', 0)],
#  '_all_fintech': [('way', 1),
#   ('inflation', 1),
#   ('kill', 1),
#   ('growth', 1),
#   ('economy', 1),
#   ('spx', 1),
#   ('spy', 1),
#   ('employment', 1),
#   ('bac', 1),
#   ('recession', 1),
#   ('fed', 1),
#   ('lower', 1),
#   ('primarily', 0),
#   ('print', 0),
#   ('printer', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('pricesrate', 0),
#   ('absolutly', 0),
#   ('powellfed', 0),
#   ('probably', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('probabilities', 0)],
#  '_romilkapoor_': [('fed', 1),
#   ('fuel', 1),
#   ('print', 1),
#   ('gas', 1),
#   ('pity', 1),
#   ('refused', 0),
#   ('powell', 0),
#   ('printer', 0),
#   ('require', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('probably', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('probabilities', 0),
#   ('report', 0),
#   ('record', 0),
#   ('rate', 0),
#   ('recession', 0)],
#  'aLtErNaTePeTeR': [('powell', 1),
#   ('question', 1),
#   ('feds', 1),
#   ('congress', 1),
#   ('fighting', 1),
#   ('make', 1),
#   ('refused', 1),
#   ('senator', 1),
#   ('answer', 1),
#   ('job', 1),
#   ('pricesrate', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('price', 0),
#   ('printer', 0),
#   ('probabilities', 0),
#   ('prices', 0),
#   ('absolutly', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('process', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('probably', 0),
#   ('qqq', 0)],
#  'alpepinnazzo': [('axp', 1),
#   ('powell', 1),
#   ('groupseconomy', 1),
#   ('inflation', 1),
#   ('card', 1),
#   ('gs', 1),
#   ('bac', 1),
#   ('spending', 1),
#   ('spx', 1),
#   ('boa', 1),
#   ('fed', 1),
#   ('ma', 1),
#   ('xlf', 1),
#   ('markets', 1),
#   ('possible', 0),
#   ('pop', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('policy', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('positive', 0),
#   ('powellfed', 0),
#   ('probably', 0),
#   ('possibility', 0),
#   ('powellduh', 0),
#   ('absolutly', 0)],
#  'annagolubova': [('powell', 1),
#   ('price', 1),
#   ('committee', 1),
#   ('fed', 1),
#   ('testifies', 1),
#   ('banking', 1),
#   ('bitcoin', 1),
#   ('senate', 1),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('absolutly', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('process', 0),
#   ('public', 0),
#   ('profits', 0),
#   ('really', 0)],
#  'askslim': [('testimony', 2),
#   ('powell', 1),
#   ('incredibly', 1),
#   ('watching', 1),
#   ('mindboggling', 1),
#   ('comments', 1),
#   ('points', 0),
#   ('policy', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('pity', 0),
#   ('powellfed', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('pivots', 0),
#   ('powellduh', 0),
#   ('probabilities', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('plan', 0),
#   ('absolutly', 0),
#   ('process', 0),
#   ('probably', 0),
#   ('realizing', 0),
#   ('report', 0)],
#  'astuteassets1': [('cointelegraph', 1),
#   ('appropriate', 1),
#   ('rises', 1),
#   ('says', 1),
#   ('rate', 1),
#   ('price', 1),
#   ('powell', 1),
#   ('hikes', 1),
#   ('bitcoin', 1),
#   ('feds', 1),
#   ('markets', 0),
#   ('makes', 0),
#   ('public', 0),
#   ('profits', 0),
#   ('process', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('ma', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('make', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0)],
#  'authenticchad': [('fed', 2),
#   ('federalreserve', 1),
#   ('fiatmoney', 1),
#   ('printer', 1),
#   ('money', 1),
#   ('bitcoin', 1),
#   ('absolutly', 0),
#   ('price', 0),
#   ('process', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('powellduh', 0),
#   ('powellfed', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('profits', 0),
#   ('qe', 0),
#   ('public', 0),
#   ('rece', 0),
#   ('reserve', 0)],
#  'cappuccinobus': [('powell', 2),
#   ('feel', 1),
#   ('comments', 1),
#   ('policy', 1),
#   ('fed', 1),
#   ('fiscal', 1),
#   ('economy', 1),
#   ('ask', 1),
#   ('bad', 1),
#   ('pricesrate', 0),
#   ('process', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('powellfed', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('public', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('profits', 0),
#   ('question', 0),
#   ('qe', 0)],
#  'chartsniping': [('talking', 1),
#   ('leading', 1),
#   ('inflation', 1),
#   ('prices', 1),
#   ('oil', 1),
#   ('powell', 1),
#   ('congress', 1),
#   ('accountn', 1),
#   ('taking', 1),
#   ('fed', 1),
#   ('plan', 0),
#   ('powellfed', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('price', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('powellduh', 0),
#   ('points', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('probabilities', 0),
#   ('positive', 0),
#   ('pivots', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('printer', 0),
#   ('process', 0),
#   ('probably', 0),
#   ('pin', 0)],
#  'charuchandna': [('fed', 1),
#   ('powell', 1),
#   ('intent', 1),
#   ('recession', 1),
#   ('possibility', 1),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('probably', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('pity', 0),
#   ('probabilities', 0),
#   ('process', 0),
#   ('peterschiff', 0),
#   ('realizing', 0),
#   ('require', 0),
#   ('report', 0),
#   ('rep', 0)],
#  'durezzadelviver': [('powell', 1),
#   ('fed', 1),
#   ('slow', 1),
#   ('inflation', 1),
#   ('growth', 1),
#   ('powellduh', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('absolutly', 0),
#   ('probably', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('probabilities', 0),
#   ('process', 0),
#   ('pin', 0),
#   ('realizing', 0),
#   ('report', 0),
#   ('rep', 0)],
#  'forexanalytix': [('theres', 1),
#   ('powell', 1),
#   ('feds', 1),
#   ('evidence', 1),
#   ('wages', 1),
#   ('outusd', 1),
#   ('flattening', 1),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('absolutly', 0),
#   ('possible', 0),
#   ('probably', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('probabilities', 0),
#   ('profits', 0),
#   ('process', 0),
#   ('realizing', 0),
#   ('report', 0)],
#  'itsarafat': [('inflation', 2),
#   ('focused', 1),
#   ('chairman', 1),
#   ('control', 1),
#   ('demandfed', 1),
#   ('powellfed', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('probably', 0),
#   ('process', 0),
#   ('pity', 0),
#   ('profits', 0),
#   ('require', 0),
#   ('report', 0)],
#  'j_que_': [('bet', 1),
#   ('room', 1),
#   ('cabinet', 1),
#   ('senate', 1),
#   ('old', 1),
#   ('smells', 1),
#   ('medicine', 1),
#   ('meeting', 1),
#   ('like', 1),
#   ('fed', 1),
#   ('positive', 0),
#   ('pop', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('points', 0),
#   ('primarily', 0),
#   ('policy', 0),
#   ('pricesrate', 0),
#   ('possibility', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('profits', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('process', 0),
#   ('absolutly', 0)],
#  'jackcuerton': [('fed', 1),
#   ('recession', 1),
#   ('rate', 1),
#   ('lead', 1),
#   ('possible', 1),
#   ('rises', 1),
#   ('plan', 0),
#   ('powellfed', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('powellduh', 0),
#   ('points', 0),
#   ('powell', 0),
#   ('process', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('pivots', 0),
#   ('policy', 0),
#   ('probably', 0),
#   ('public', 0),
#   ('profits', 0),
#   ('really', 0),
#   ('require', 0)],
#  'l_malen': [('committee', 1),
#   ('senate', 1),
#   ('speakers', 1),
#   ('wednesday', 1),
#   ('week', 1),
#   ('banking', 1),
#   ('testifies', 1),
#   ('jpowell', 1),
#   ('today', 1),
#   ('feds', 1),
#   ('ho', 1),
#   ('powell', 0),
#   ('price', 0),
#   ('prices', 0),
#   ('pricesrate', 0),
#   ('primarily', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possibility', 0),
#   ('possible', 0),
#   ('printer', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('pity', 0),
#   ('print', 0)],
#  'litaruby': [('just', 2),
#   ('opinionate', 1),
#   ('fed', 1),
#   ('little', 1),
#   ('given', 1),
#   ('godliness', 1),
#   ('anythi', 1),
#   ('powellfed', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('process', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('probably', 0),
#   ('public', 0),
#   ('profits', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0)],
#  'markets_ya': [('commodities', 1),
#   ('action', 1),
#   ('session', 1),
#   ('check', 1),
#   ('strategies', 1),
#   ('trading', 1),
#   ('price', 1),
#   ('todays', 1),
#   ('absolutly', 0),
#   ('powell', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possibility', 0),
#   ('possible', 0),
#   ('printer', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('print', 0),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('pin', 0),
#   ('rep', 0)],
#  'masked_investor': [('doing', 1),
#   ('told', 1),
#   ('jerome', 1),
#   ('job', 1),
#   ('inflation', 1),
#   ('wasnt', 1),
#   ('powell', 1),
#   ('transitoryoh', 1),
#   ('oh', 1),
#   ('price', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('probabilities', 0),
#   ('absolutly', 0),
#   ('probably', 0),
#   ('pin', 0)],
#  'mckonomy': [('difference', 1),
#   ('prices', 1),
#   ('hill', 1),
#   ('people', 1),
#   ('understand', 1),
#   ('dont', 1),
#   ('oil', 1),
#   ('gasoline', 1),
#   ('capitol', 1),
#   ('probably', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('absolutly', 0),
#   ('price', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('powellfed', 0),
#   ('process', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('realizing', 0)],
#  'pleasantville73': [('probably', 1),
#   ('think', 1),
#   ('fed', 1),
#   ('literal', 1),
#   ('don', 1),
#   ('financialjuice', 1),
#   ('words', 1),
#   ('operative', 1),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('process', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('powell', 0),
#   ('qe', 0),
#   ('profits', 0)],
#  'realLisaDaly': [('committee', 1),
#   ('powell', 1),
#   ('getting', 1),
#   ('jerome', 1),
#   ('banking', 1),
#   ('senator', 1),
#   ('senate', 1),
#   ('grilled', 1),
#   ('nevada', 1),
#   ('soun', 1),
#   ('trying', 1),
#   ('powellduh', 0),
#   ('probabilities', 0),
#   ('pivots', 0),
#   ('printer', 0),
#   ('plan', 0),
#   ('print', 0),
#   ('points', 0),
#   ('policy', 0),
#   ('possible', 0),
#   ('pop', 0),
#   ('positive', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('possibility', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('primarily', 0),
#   ('absolutly', 0),
#   ('probably', 0)],
#  'shreyyy30': [('knows', 1),
#   ('tools', 1),
#   ('fed', 1),
#   ('mysteries', 1),
#   ('world', 1),
#   ('inflation', 1),
#   ('powell', 1),
#   ('control', 1),
#   ('does', 1),
#   ('price', 0),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('absolutly', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('probably', 0),
#   ('profits', 0),
#   ('process', 0)],
#  'sidd1307': [('rate', 2),
#   ('lik', 1),
#   ('way', 1),
#   ('happen', 1),
#   ('won', 1),
#   ('overnight', 1),
#   ('increases', 1),
#   ('fund', 1),
#   ('fed', 1),
#   ('prices', 0),
#   ('pricesrate', 0),
#   ('price', 0),
#   ('primarily', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('print', 0),
#   ('absolutly', 0),
#   ('possible', 0),
#   ('powell', 0),
#   ('probabilities', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('printer', 0),
#   ('public', 0),
#   ('probably', 0)],
#  'sohaibeth': [('amp', 2),
#   ('buy', 2),
#   ('sell', 1),
#   ('crypto', 1),
#   ('th', 1),
#   ('panicking', 1),
#   ('russians', 1),
#   ('holdings', 1),
#   ('stocks', 1),
#   ('fed', 1),
#   ('prices', 0),
#   ('pricesrate', 0),
#   ('primarily', 0),
#   ('print', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possibility', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('probabilities', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('printer', 0),
#   ('absolutly', 0),
#   ('probably', 0)],
#  'soldatthetop': [('right', 1),
#   ('recession', 1),
#   ('totally', 1),
#   ('brewing', 1),
#   ('jeannasmialek', 1),
#   ('notable', 1),
#   ('work', 1),
#   ('process', 1),
#   ('fed', 1),
#   ('false', 1),
#   ('policy', 0),
#   ('points', 0),
#   ('pivots', 0),
#   ('printer', 0),
#   ('plan', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('probabilities', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('powell', 0),
#   ('public', 0),
#   ('probably', 0)],
#  'sumitkapoor16': [('powell', 2),
#   ('tame', 1),
#   ('chair', 1),
#   ('inflationfed', 1),
#   ('inflation', 1),
#   ('jerome', 1),
#   ('bank', 1),
#   ('raising', 1),
#   ('rates', 1),
#   ('interestrates', 1),
#   ('central', 1),
#   ('says', 1),
#   ('fed', 1),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('powellduh', 0),
#   ('policy', 0),
#   ('powellfed', 0),
#   ('price', 0),
#   ('possible', 0),
#   ('prices', 0),
#   ('pricesrate', 0),
#   ('primarily', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('print', 0),
#   ('printer', 0),
#   ('profits', 0)],
#  'thakre_aarya': [('getting', 1),
#   ('operating', 1),
#   ('fed', 1),
#   ('peterschiff', 1),
#   ('history', 1),
#   ('althou', 1),
#   ('territory', 1),
#   ('senator', 1),
#   ('secrecy', 1),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('absolutly', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('probabilities', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('possible', 0),
#   ('profits', 0),
#   ('probably', 0)],
#  'themacrotweet': [('fomc', 1),
#   ('fintwit', 1),
#   ('economy', 1),
#   ('economics', 1),
#   ('payrolls', 1),
#   ('seasonally', 1),
#   ('forex', 1),
#   ('utilities', 1),
#   ('adjustedfed', 1),
#   ('finance', 1),
#   ('employees', 1),
#   ('printer', 0),
#   ('probabilities', 0),
#   ('print', 0),
#   ('probably', 0),
#   ('primarily', 0),
#   ('process', 0),
#   ('pricesrate', 0),
#   ('absolutly', 0),
#   ('prices', 0),
#   ('public', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('profits', 0)],
#  'vinniepalma': [('risk', 1),
#   ('assets', 1),
#   ('comments', 1),
#   ('hour', 1),
#   ('pop', 1),
#   ('powell', 1),
#   ('crude', 1),
#   ('following', 1),
#   ('equity', 1),
#   ('hope', 1),
#   ('amp', 1),
#   ('false', 1),
#   ('makes', 1),
#   ('recession', 0),
#   ('possible', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('refused', 0),
#   ('prices', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possibility', 0),
#   ('printer', 0),
#   ('positive', 0),
#   ('rep', 0),
#   ('policy', 0),
#   ('report', 0),
#   ('points', 0),
#   ('plan', 0)],
#  'wallstmaster': [('federalreserve', 1),
#   ('ukraine', 1),
#   ('high', 1),
#   ('jerome', 1),
#   ('broke', 1),
#   ('certainly', 1),
#   ('inflation', 1),
#   ('war', 1),
#   ('powellfed', 1),
#   ('absolutly', 0),
#   ('price', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('powellduh', 0),
#   ('probably', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('probabilities', 0),
#   ('profits', 0),
#   ('process', 0)],
#  'x2da4': [('suck', 1),
#   ('hoping', 1),
#   ('powell', 1),
#   ('mistakes', 1),
#   ('testimony', 1),
#   ('policy', 1),
#   ('guy', 1),
#   ('thoughtless', 1),
#   ('fall', 1),
#   ('fed', 1),
#   ('summarysenators', 1),
#   ('pin', 1),
#   ('pricesrate', 0),
#   ('price', 0),
#   ('primarily', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('prices', 0),
#   ('positive', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('printer', 0),
#   ('pop', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('pivots', 0),
#   ('pivotmarketsequitiesfedfederalreserve', 0),
#   ('print', 0),
#   ('absolutly', 0),
#   ('probabilities', 0)],
#  'xglobalmarkets': [('fed', 2),
#   ('june', 2),
#   ('rates', 1),
#   ('rate', 1),
#   ('xglobalmarkets', 1),
#   ('funds', 1),
#   ('inflation', 1),
#   ('vs', 1),
#   ('economy', 1),
#   ('effective', 1),
#   ('probabilities', 0),
#   ('printer', 0),
#   ('print', 0),
#   ('primarily', 0),
#   ('pricesrate', 0),
#   ('prices', 0),
#   ('absolutly', 0),
#   ('process', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('powell', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('probably', 0)],
#  'yellowdijon': [('love', 1),
#   ('public', 1),
#   ('people', 1),
#   ('hearings', 1),
#   ('id', 1),
#   ('powell', 1),
#   ('budget', 1),
#   ('inviting', 1),
#   ('committ', 1),
#   ('finance', 1),
#   ('recent', 0),
#   ('primarily', 0),
#   ('prices', 0),
#   ('record', 0),
#   ('price', 0),
#   ('powellfed', 0),
#   ('powellduh', 0),
#   ('possible', 0),
#   ('possibility', 0),
#   ('refused', 0),
#   ('positive', 0),
#   ('pop', 0),
#   ('rep', 0),
#   ('policy', 0),
#   ('points', 0),
#   ('plan', 0),
#   ('report', 0),
#   ('pivots', 0),
#   ('pricesrate', 0),
#   ('print', 0)]}
