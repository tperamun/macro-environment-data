# %%
import gspread
import pandas as pd

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
service_account = gspread.service_account(filename="/Users/timal/.config/gspread/service_account.json")
xom_chpt_sheet = service_account.open('XOM_CHPT')
work_sheet = xom_chpt_sheet.worksheet('XOM_CHPT')

# %%
df = pd.DataFrame(work_sheet.get_all_values())

# %%
df.rename(columns=df.iloc[0], inplace=True)
df.drop(df.index[0], inplace=True)
df
# Out:
#                  XOM             CHPT
# 1    -0.008324076487    -0.0192893401
# 2     -0.03511475468   0.005175983437
# 3    0.0001451095637  -0.001029866117
# 4     -0.01986078924   0.001030927835
# 5      0.02425679445    0.00411946447
# ..               ...              ...
# 139    0.04435004189    0.06063522618
# 140    0.06237747592      0.220508167
# 141    0.01537042793    0.08327137546
# 142    0.01382584575   -0.01235415237
# 143   -0.05544495377   -0.07157748436
#
# [143 rows x 2 columns]

# %%
# %matplotlib inline
plt.figure(figsize=(80,80))
plt.scatter(df.XOM, df.CHPT)

# %%
x_train, x_test, y_train, y_test = train_test_split(df.XOM, df.CHPT, test_size=0.2, random_state=10)
clf = LinearRegression()
clf.fit(x_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
clf.score(x_test.values.reshape(-1,1), y_test)
# Out:
# -0.0961778537572544
