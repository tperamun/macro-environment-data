# %%
import pandas as pd

data = pd.read_pickle('clean_corpus.pkl')
data
# Out:
#                                                             tweets
# hunter62046908                chpt top analyst price target today
# Gambiste1             rt isentiment idex ok  chpt blnk muln evgo
# GinoDeLaRose     ◦letsgo spy amc gme muln hymc bbig rdbx  sndl ...
# EssaronyMoha                                                chpt
# shortvolumes      short sale volume not short interest for chpt...
# ...                                                            ...
# Snakecase_                                    chpt from zarickman
# zarickman                                          snakecase chpt
# BullishCesar100               mrmikeinvesting youre not into chpt
# TraderJike         chpt chart suggesting a possible move down to
# HellCatTrader              still holding puts  aapl pltr amd chpt
#
# [107 rows x 1 columns]

# %%
from textblob import TextBlob

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data['tweets'].apply(pol)
data['subjectivity'] = data['tweets'].apply(sub)

data
# Out:
#                                                             tweets  polarity  \
# hunter62046908                chpt top analyst price target today   0.500000
# Gambiste1             rt isentiment idex ok  chpt blnk muln evgo    0.500000
# GinoDeLaRose     ◦letsgo spy amc gme muln hymc bbig rdbx  sndl ...  0.000000
# EssaronyMoha                                                chpt    0.000000
# shortvolumes      short sale volume not short interest for chpt...  0.000000
# ...                                                            ...       ...
# Snakecase_                                    chpt from zarickman   0.000000
# zarickman                                          snakecase chpt   0.000000
# BullishCesar100               mrmikeinvesting youre not into chpt   0.000000
# TraderJike         chpt chart suggesting a possible move down to   -0.077778
# HellCatTrader              still holding puts  aapl pltr amd chpt   0.000000
#
#                  subjectivity
# hunter62046908       0.500000
# Gambiste1            0.500000
# GinoDeLaRose         0.000000
# EssaronyMoha         0.000000
# shortvolumes         0.300000
# ...                       ...
# Snakecase_           0.000000
# zarickman            0.000000
# BullishCesar100      0.000000
# TraderJike           0.644444
# HellCatTrader        0.000000
#
# [107 rows x 3 columns]

# %%
# Visualialize results

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]

for index, user in enumerate(data.index):
    
    x = data.polarity.loc[user]
    y = data.subjectivity.loc[user]
    
    plt.scatter(x, y, color='blue')
    
    plt.xlim(-0.01, .12)
    
plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<--Negative --------Positive -->', fontsize=15)
plt.ylabel('<--Facts -------- Opinions -->', fontsize=15)

plt.show()
