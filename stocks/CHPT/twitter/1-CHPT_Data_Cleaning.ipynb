# %%
import sys, os, pickle
import tweepy as tw
import pandas as pd

# %%
def twitter_auth():
    try:
        consumer_key = os.environ['TWITTER_API_KEY']
        consumer_secret = os.environ['TWITTER_API_SECRET']
        access_token = os.environ['TWITTER_API_ACCESS_TOKEN']
        access_secret=os.environ['TWITTER_API_ACCESS_TOKEN_SECRET']
    except KeyError:
        sys.stderr.write("Environment variable not set\n")
        sys.exit(1)
    
    auth = tw.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    
    return auth

# %%
def get_twitter_client():
    auth = twitter_auth()
    client = tw.API(auth, wait_on_rate_limit=True)
    return client

# %%
SEARCH_TERM = "$CHPT"
date_since = '2022-06-24'
NUM_TWEETS = 1000

# %%
client = get_twitter_client()
tweets = tw.Cursor(client.search_tweets, q=SEARCH_TERM, lang='en', since=date_since).items(NUM_TWEETS)
saved_tweets = {}

for tweet in tweets:
    saved_tweets[tweet.user.screen_name] = tweet.text
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since

# %%
saved_tweets
# Out:
# {'hunter62046908': "$CHPT ~'Top analyst price target today. https://t.co/OsCHYh8F00",
#  'Gambiste1': 'RT @GinoDeLaRose: ◦#LetsGo $SPY $AMC $GME $MULN $HYMC $BBIG $RDBX  $SNDL $TWTR $CALA $NILE $BBBY $LCID $HSTO $GGPI $CENN $CEI $OP $CHPT $DW…',
#  'GinoDeLaRose': '◦#LetsGo $SPY $AMC $GME $MULN $HYMC $BBIG $RDBX  $SNDL $TWTR $CALA $NILE $BBBY $LCID $HSTO $GGPI $CENN $CEI $OP… https://t.co/iksnegEUIr',
#  'EssaronyMoha': '$CHPT 👌✌️ https://t.co/6p5lEO4n4r',
#  'shortvolumes': 'Short sale volume (not short interest) for $NET at 2022-06-23 is 59%. https://t.co/JxgEjyWt5B $JNPR 66% $TCRT 58% $LUV 58% $CHPT 55%',
#  'trackfunds': 'Increase in No. Funds Holding:\n\n$VALE = 57\n$DTE = 39\n$BA = 33\n$CHPT = 17\n$RTM = 17\n$CUZ = 7\n$JBLU = 5\n\nSee Which Fu… https://t.co/H4KFezdO03',
#  'SurrenB': 'RT @AimanBbt: Tough market recently, not many nice daily setups, played $CHPT for potential momentum which sadly failed! -0.5R\n\n@BearBullTr…',
#  'RustyCas': '@RevShark Not sure who’ll be building them, but EV’s are inevitable. Don’t hear much talk about EV infrastructure. $CHPT',
#  'MC_OptionTrades': '$CHPT 01-Jul-22 ATM Implied Vol Increases +3.6%. Straddle Implies a Move of ±10.8% https://t.co/dfyBRwxonn',
#  'tiedyejamber': 'RT @ExplorerTx: Form 10 on deck for $SIRC. Form has been in the hands of auditors. Expect the filing any day now. Undervalued is an underst…',
#  'Gary_Will120': '$CHPT Top analyst price target today https://t.co/9hbd1vhppf',
#  'marioc48': '@aztecs99 What levels are you looking in regards to $chpt ?',
#  'volumeticker': 'RT @datadili: ChargePoint Holdings, Inc. traded 18% above average volume, $CHPT closed up 9.12%',
#  'BrianOl38959945': 'RT @ExplorerTx: Form 10 on deck for $SIRC. Form has been in the hands of auditors. Expect the filing any day now. Undervalued is an underst…',
#  'alerts_real': "$CHPT Don't miss the next move in a few  hours,, https://t.co/GeJEKHJZp0",
#  'JunaidBinIqbal3': '@Benzinga $chpt',
#  'Dakippa': '$CHPT chart was looking sweet and is still looking sweet https://t.co/uf4I0zEAlp',
#  'chipsRdwn': '+4.4R on $CVX +3.6 on $CHPT +3.1 on $HD and gave most of it back convinced I was right fighting with $META. I Broke… https://t.co/1ydX8O14yr'}

# %%
# Pickle tweets

with open('tweets.txt', 'wb') as file:
    pickle.dump(saved_tweets, file)

# %%
with open('tweets.txt', 'rb') as file:
    data = pickle.load(file)

# %%
len(data)
# Out:
# 107

# %%
# Apply first round of data cleaning

import re
import string

def clean_text_round1(text):
    '''Make text lowercase and remove punctuation'''
    
    text = text.lower()
    text = re.sub('\[.*?\]','', text)
    text = re.sub('["%s"]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(r'http\S+', '', text)
    
    return text

data_clean = {}

for user, tweet in data.items():
    data_clean[user] = clean_text_round1(tweet)

# %%
data_clean
# Out:
# {'hunter62046908': 'chpt top analyst price target today ',
#  'Gambiste1': 'rt isentiment idex ok 👇👇👇 \n\nchpt blnk muln evgo 📈 ',
#  'GinoDeLaRose': '◦letsgo spy amc gme muln hymc bbig rdbx  sndl twtr cala nile bbby lcid hsto ggpi cenn cei op… ',
#  'EssaronyMoha': 'chpt 👌✌️ ',
#  'shortvolumes': ' short sale volume not short interest for chpt is   w  xhb  wve  mcd ',
#  'trackfunds': 'no of funds increasing holding\no  \ngnrc  \nchpt  \nbros  \ncns  \natip  \ncut  \nsee w… ',
#  'SurrenB': 'rt aimanbbt tough market recently not many nice daily setups played chpt for potential momentum which sadly failed \n\nbearbulltr…',
#  'RustyCas': 'revshark not sure who’ll be building them but ev’s are inevitable don’t hear much talk about ev infrastructure chpt',
#  'MC_OptionTrades': 'chpt makes an outsized move  the  option straddle expiring tomorrow implies a ± move ',
#  'tiedyejamber': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'Gary_Will120': 'chpt top analyst price target today ',
#  'marioc48': ' what levels are you looking in regards to chpt ',
#  'volumeticker': 'rt datadili chargepoint holdings inc traded  above average volume chpt closed up ',
#  'BrianOl38959945': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'alerts_real': 'chpt dont miss the next move in a few  hours ',
#  'JunaidBinIqbal3': 'benzinga chpt',
#  'Dakippa': 'chpt chart was looking sweet and is still looking sweet ',
#  'chipsRdwn': ' on cvx  on chpt  on hd and gave most of it back convinced i was right fighting with meta i broke… ',
#  'JensenXavier1': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'EquitySystems': 'my top  strongest stocks action summary thu \n\n  niolonghold\n  babalongcaution\n  jdlongcaution… ',
#  'FlyinNate': 'rt boredbilionaire watchlist for tomorrow \nfdx snow vrm oxy ftnt tlty swbi petz u baba sq bb srpt de db dna celh bac …',
#  'Fredbenz0': 'chpt 💰↔️⬅️\n\npremium in play\n \n\ntechnicals\n🚦 lt  wait for more price destruct… ',
#  'TradeWithAlerts': 'nice print for chpt size  price  amount  time \nsee more \nj… ',
#  'ErroneousTrades': 'look at the  bullish momentum on chargepoint chpt after crossing back up on the daily there is money to be made… ',
#  'dewmboom': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'ogswings': 'peeled off some chpt for quick gainz still holdin most gonna watch for re entry\npt still  ish ',
#  'datadili': 'chargepoint holdings inc traded  above average volume chpt closed up ',
#  'jar_that': 'gerberkawasaki ggpi psny amp chpt the perfect marriage if potus amp secgranholm arent going to invest in oil t… ',
#  'new2tweetter': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'BoredBilionaire': 'watchlist for tomorrow \nfdx snow vrm oxy ftnt tlty swbi petz u baba sq bb srpt de db dna celh… ',
#  'BetterScript': 'important like what come like ill meet you at\n\nsweet kitty dag kava chpt nft',
#  'JakeRayel': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'galelron': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'ppunke': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'sturdherd': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'Mercutos': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'barefootcash': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  '2outted': 'rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…',
#  'ExplorerTx': 'form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an… ',
#  'TShortalgo': 'chpt trading ideas  awaiting short signal  profitability based on  trades profit factor is  learn more… ',
#  'AimanBbt': 'tough market recently not many nice daily setups played chpt for potential momentum which sadly failed … ',
#  'stocknewsdotcom': 'chpt shares of ev charging network operator chargepoint holdings chpt have rallied over the past month followin… ',
#  'justphiltrading': 'chpt standout trade spotted in my flow  strike calls opened up buytoopen about  cents otm at t… ',
#  'Dubyatrades': ' days ago i posted a chpt call play in tradingcollectv discord and just sold my my calls for  lets go stocks stockstowatch',
#  'TradingForex_eu': 'rt kellyjohnsonfx only muln is red all other electric car manufacturers are in green today li nio lcid chpt and xpev all 🚀',
#  'CFDoptions': 'rt kellyjohnsonfx only muln is red all other electric car manufacturers are in green today li nio lcid chpt and xpev all 🚀',
#  'TroySpencerOTC': 'rt kellyjohnsonfx only muln is red all other electric car manufacturers are in green today li nio lcid chpt and xpev all 🚀',
#  'KellyJohnsonFX': 'only muln is red all other electric car manufacturers are in green today li nio lcid chpt and xpev all 🚀',
#  '_FighterJet_': 'chpt    ',
#  'DataMrp': 'rt dubyatrades  days ago i posted a chpt call play in tradingcollectv discord and just sold my my calls for  lets go stocks stoc…',
#  'TWAOptions': 'chpt strike  expiration  call  price  size  time  \npremium ',
#  'WallStSnacks': 'bull forecasts\njune    pdt\n🐂🐂🐂🐂🐂\nticker  log change intraday\ngld  \nchpt  \nwgo  … ',
#  'SynnTrades': 'y’all didn’t believe in me but dg chpt did ',
#  'Thre3_Bucks': 'chpt coming up on that downward trend line that is literally almost a year old if we can successfully flip that l… ',
#  'secmaster420': 'jakewujastyk jake please do chpt thanks',
#  'TommyScanner': 'tstalert is chpt next to cut bait as bob and chris nonchalantly say for very deep losses the community talks',
#  'TeviLawson13': 'chpt news investment bank b riley initiated coverage on chargepoint w a buy rating and  price target\n\n“b… ',
#  'StockAlarms': 'bullishalert \nbullish stock alert chpt at \n\nthis alert is meant for swing and day traders for details pl… ',
#  'Tickeron': 'chpt in  uptrend advancing for three consecutive days on june   view odds for this and other indic… ',
#  'tugasdatmin': 'rt ariesflow chpt   call\n\ntype large\ntime \ntotal size  contracts\ntotal value \naverage price …',
#  'dan_vella_': 'wolffinancial chpt looks like it bottomed… can we have some thoughts on that name',
#  'TampaWINNER': 'rt eduwallstreet campbell ca business electric vehicle ev charging networks chargepoint chargepointnet \nchpt\n\nsectors consume…',
#  'eduWallStreet': 'campbell ca business electric vehicle ev charging networks chargepoint chargepointnet \nchpt\n\nsectors co… ',
#  'otctrades_mb': 'elek secures fleet from tsla to start firstever allelectric vehicle rental car organization\n\nblnk wbx evgo chpt cpsh muln',
#  'shinedown_fan76': 'rt otctradesmb break out is near for elek 📈 electricvehicles otcmarkets \n\ntsla blnk wbx evgo chpt cpsh muln',
#  'theresa_perrin': 'chpt and plug are running  watch fcel it always follows',
#  'Vikram7321': 'keep your patience on clov \n\n\nwe have two choice hold clov or sell clov you decide\n\nocgn… ',
#  '_GalacticChild': 'firedupwealth chpt dkng sofi crox 👀',
#  'finbrain_t': 'lowest options putcall ratio stocks   bullish 🐂\n\n chpt   \n bbig   \n muln    \n slb    … ',
#  'GivingTrading': 'throat punch thursday has made me impatient todaytook profits on chpt a bit earlyprofit is good… ',
#  'VetTechTrader': 'josh now pounding chpt every day forgot about mttr after cratered  and same with rblx where pulled the plug… ',
#  'Mike65462413': 'rt marketrebels nio    put\ntqqq    put\nf    put\nvrm    put\nbac …',
#  'bigmikehands': 'rt marketrebels nio    put\ntqqq    put\nf    put\nvrm    put\nbac …',
#  'Flower_Power_67': 'fastmoneyespresso\nfinal calls\nbrenda vingiello —gt buy zts\npete najarian —gt buy xle october  puts\njosh brown —… ',
#  'ethanmgfx': 'rt marketrebels nio    put\ntqqq    put\nf    put\nvrm    put\nbac …',
#  'optionwaves': 'chpt  jul   put ⬇️🌊\nunderlying \n difference \ndaily  volume \nvolume \no… ',
#  'WSArabicNews': 'nio    put\ntqqq    put\nf    put\nvrm    put… ',
#  'CarlPHI22278711': 'rt marketrebels nio    put\ntqqq    put\nf    put\nvrm    put\nbac …',
#  'MarketRebels': 'nio    put\ntqqq    put\nf    put\nvrm    put… ',
#  'GailHedglin': 'downtown wow chpt are you kidding its losing  no pe shorted  negative cash flow and operating cash  couldnt be any worse lol',
#  'keithster1': 'wallstreetbets reddit robinhoodapp ibkr thinkorswim tastyworks halftimereport josh downtown recommends again chpt as final trade',
#  'AZTraderJim': 'chpt one to keep an eye on here nice weekly reversal candle last week amp good tail again this week butting up aga… ',
#  'RareSterling': ' election campaign camels 🐪\nchpt tsla blnk spwr\ndo your earnings transcript 🔬\n🔮👀 alternative energy incentives… ',
#  'JMTradezxcii': 'not an investor but its ridiculous the price of chpt wbx evgo then look at allg  only ebita positive and… ',
#  'StockswithLenny': 'chpt\n\nabout to retest the downward trendline again look how many times it got rejected here can it break this ti… ',
#  'stennypocksman': 'blnk and chpt calls are printing today \n\nready for nxmr to run run run run runnnnn',
#  'droneview360': 'chpt ✅ 🤓 ',
#  'AriesFlow': 'chpt   call\n\ntype large\ntime \ntotal size  contracts\ntotal value \naverage pr… ',
#  'Options_Experts': 'chpt  best business model ever  us govt pays u to install ev charging stations everywhere you reap the quarterl… ',
#  'CeoPurchases': '🤡inverse cramer🤡\namat  opinionbuy\namn  opinionbuy\nbaba  opinionsell\nbros da… ',
#  'stadestrades': 'wl  spy qqq chpt intc ',
#  'MaiteMerenda': 'chpt awaiting for short signal support and resistance from  to  free trial at … ',
#  'OpinicusHolding': 'top increases in open interest\n\n kr   put\n bbd   call \n chpt   call\n dvn   call\n… ',
#  'Jarvis_Alerts': 'chpt   ↑↑  🚀 totalday \nunusualactivity\n\nsignup free for beta ver… ',
#  'damienj410': 'rt upboptionmil todays top stock option open interest changes f sofi kr dkng agnc clvs pcg fsk chpt pins dis intc ',
#  'i_sentiment': 'idex ok 👇👇👇 \n\nchpt blnk muln evgo 📈 ',
#  'RGB_NFTs_': 'rt betterscript of the turkey really yeah so youre next thing you know im in mexico\n\nsweet kitty dag kava chpt nft',
#  'ev_advocate': 'spacpicks like plby dumped on ticker change like qs dumped on ticker change or chpt they have no clue',
#  'TheBetterBull': 'lenraleigh definitely agree though jb likes being private so right now sticking with licy alongside lac then charging chpt 🔋',
#  'paynej247': 'rt upboptionmil todays top stock option open interest changes f sofi kr dkng agnc clvs pcg fsk chpt pins dis intc ',
#  'foty2015': 'tradytics chpt boom 💥  done ✔️',
#  'SweepCastApp': 'sweepcast 🦍 unusual options observed  chpt with our scanner on  call expiring  worth 🐂  start yo… ',
#  'Snakecase_': 'chpt from zarickman ',
#  'zarickman': 'snakecase chpt 👁',
#  'BullishCesar100': 'mrmikeinvesting youre not into chpt ',
#  'TraderJike': 'chpt chart suggesting a possible move down to  ',
#  'HellCatTrader': 'still holding puts 😎 \n\naapl pltr amd chpt '}

# %%
# Round 2 cleaning

import emoji

def clean_text_round2(text):
    
    text = emoji.get_emoji_regexp().sub(r'', text)
    text = text.replace('\n', "")
    
    return text

data_clean_new = {}

for user, tweet in data_clean.items():
    data_clean_new[user] = [clean_text_round2(tweet)]
    
data_clean_new
# Out:
# /var/folders/ly/b0d5ymx54rd755r8d506sd000000gn/T/ipykernel_72945/197693976.py:7: DeprecationWarning: 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'
#   text = emoji.get_emoji_regexp().sub(r'', text)
# {'hunter62046908': ['chpt top analyst price target today '],
#  'Gambiste1': ['rt isentiment idex ok  chpt blnk muln evgo  '],
#  'GinoDeLaRose': ['◦letsgo spy amc gme muln hymc bbig rdbx  sndl twtr cala nile bbby lcid hsto ggpi cenn cei op… '],
#  'EssaronyMoha': ['chpt  '],
#  'shortvolumes': [' short sale volume not short interest for chpt is   w  xhb  wve  mcd '],
#  'trackfunds': ['no of funds increasing holdingo  gnrc  chpt  bros  cns  atip  cut  see w… '],
#  'SurrenB': ['rt aimanbbt tough market recently not many nice daily setups played chpt for potential momentum which sadly failed bearbulltr…'],
#  'RustyCas': ['revshark not sure who’ll be building them but ev’s are inevitable don’t hear much talk about ev infrastructure chpt'],
#  'MC_OptionTrades': ['chpt makes an outsized move  the  option straddle expiring tomorrow implies a ± move '],
#  'tiedyejamber': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'Gary_Will120': ['chpt top analyst price target today '],
#  'marioc48': [' what levels are you looking in regards to chpt '],
#  'volumeticker': ['rt datadili chargepoint holdings inc traded  above average volume chpt closed up '],
#  'BrianOl38959945': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'alerts_real': ['chpt dont miss the next move in a few  hours '],
#  'JunaidBinIqbal3': ['benzinga chpt'],
#  'Dakippa': ['chpt chart was looking sweet and is still looking sweet '],
#  'chipsRdwn': [' on cvx  on chpt  on hd and gave most of it back convinced i was right fighting with meta i broke… '],
#  'JensenXavier1': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'EquitySystems': ['my top  strongest stocks action summary thu   niolonghold  babalongcaution  jdlongcaution… '],
#  'FlyinNate': ['rt boredbilionaire watchlist for tomorrow fdx snow vrm oxy ftnt tlty swbi petz u baba sq bb srpt de db dna celh bac …'],
#  'Fredbenz0': ['chpt premium in play technicals lt  wait for more price destruct… '],
#  'TradeWithAlerts': ['nice print for chpt size  price  amount  time see more j… '],
#  'ErroneousTrades': ['look at the  bullish momentum on chargepoint chpt after crossing back up on the daily there is money to be made… '],
#  'dewmboom': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'ogswings': ['peeled off some chpt for quick gainz still holdin most gonna watch for re entrypt still  ish '],
#  'datadili': ['chargepoint holdings inc traded  above average volume chpt closed up '],
#  'jar_that': ['gerberkawasaki ggpi psny amp chpt the perfect marriage if potus amp secgranholm arent going to invest in oil t… '],
#  'new2tweetter': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'BoredBilionaire': ['watchlist for tomorrow fdx snow vrm oxy ftnt tlty swbi petz u baba sq bb srpt de db dna celh… '],
#  'BetterScript': ['important like what come like ill meet you atsweet kitty dag kava chpt nft'],
#  'JakeRayel': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'galelron': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'ppunke': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'sturdherd': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'Mercutos': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'barefootcash': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  '2outted': ['rt explorertx form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an underst…'],
#  'ExplorerTx': ['form  on deck for sirc form has been in the hands of auditors expect the filing any day now undervalued is an… '],
#  'TShortalgo': ['chpt trading ideas  awaiting short signal  profitability based on  trades profit factor is  learn more… '],
#  'AimanBbt': ['tough market recently not many nice daily setups played chpt for potential momentum which sadly failed … '],
#  'stocknewsdotcom': ['chpt shares of ev charging network operator chargepoint holdings chpt have rallied over the past month followin… '],
#  'justphiltrading': ['chpt standout trade spotted in my flow  strike calls opened up buytoopen about  cents otm at t… '],
#  'Dubyatrades': [' days ago i posted a chpt call play in tradingcollectv discord and just sold my my calls for  lets go stocks stockstowatch'],
#  'TradingForex_eu': ['rt kellyjohnsonfx only muln is red all other electric car manufacturers are in green today li nio lcid chpt and xpev all '],
#  'CFDoptions': ['rt kellyjohnsonfx only muln is red all other electric car manufacturers are in green today li nio lcid chpt and xpev all '],
#  'TroySpencerOTC': ['rt kellyjohnsonfx only muln is red all other electric car manufacturers are in green today li nio lcid chpt and xpev all '],
#  'KellyJohnsonFX': ['only muln is red all other electric car manufacturers are in green today li nio lcid chpt and xpev all '],
#  '_FighterJet_': ['chpt    '],
#  'DataMrp': ['rt dubyatrades  days ago i posted a chpt call play in tradingcollectv discord and just sold my my calls for  lets go stocks stoc…'],
#  'TWAOptions': ['chpt strike  expiration  call  price  size  time  premium '],
#  'WallStSnacks': ['bull forecastsjune    pdtticker  log change intradaygld  chpt  wgo  … '],
#  'SynnTrades': ['y’all didn’t believe in me but dg chpt did '],
#  'Thre3_Bucks': ['chpt coming up on that downward trend line that is literally almost a year old if we can successfully flip that l… '],
#  'secmaster420': ['jakewujastyk jake please do chpt thanks'],
#  'TommyScanner': ['tstalert is chpt next to cut bait as bob and chris nonchalantly say for very deep losses the community talks'],
#  'TeviLawson13': ['chpt news investment bank b riley initiated coverage on chargepoint w a buy rating and  price target“b… '],
#  'StockAlarms': ['bullishalert bullish stock alert chpt at this alert is meant for swing and day traders for details pl… '],
#  'Tickeron': ['chpt in  uptrend advancing for three consecutive days on june   view odds for this and other indic… '],
#  'tugasdatmin': ['rt ariesflow chpt   calltype largetime total size  contractstotal value average price …'],
#  'dan_vella_': ['wolffinancial chpt looks like it bottomed… can we have some thoughts on that name'],
#  'TampaWINNER': ['rt eduwallstreet campbell ca business electric vehicle ev charging networks chargepoint chargepointnet chptsectors consume…'],
#  'eduWallStreet': ['campbell ca business electric vehicle ev charging networks chargepoint chargepointnet chptsectors co… '],
#  'otctrades_mb': ['elek secures fleet from tsla to start firstever allelectric vehicle rental car organizationblnk wbx evgo chpt cpsh muln'],
#  'shinedown_fan76': ['rt otctradesmb break out is near for elek  electricvehicles otcmarkets tsla blnk wbx evgo chpt cpsh muln'],
#  'theresa_perrin': ['chpt and plug are running  watch fcel it always follows'],
#  'Vikram7321': ['keep your patience on clov we have two choice hold clov or sell clov you decideocgn… '],
#  '_GalacticChild': ['firedupwealth chpt dkng sofi crox '],
#  'finbrain_t': ['lowest options putcall ratio stocks   bullish  chpt    bbig    muln     slb    … '],
#  'GivingTrading': ['throat punch thursday has made me impatient todaytook profits on chpt a bit earlyprofit is good… '],
#  'VetTechTrader': ['josh now pounding chpt every day forgot about mttr after cratered  and same with rblx where pulled the plug… '],
#  'Mike65462413': ['rt marketrebels nio    puttqqq    putf    putvrm    putbac …'],
#  'bigmikehands': ['rt marketrebels nio    puttqqq    putf    putvrm    putbac …'],
#  'Flower_Power_67': ['fastmoneyespressofinal callsbrenda vingiello —gt buy ztspete najarian —gt buy xle october  putsjosh brown —… '],
#  'ethanmgfx': ['rt marketrebels nio    puttqqq    putf    putvrm    putbac …'],
#  'optionwaves': ['chpt  jul   put underlying  difference daily  volume volume o… '],
#  'WSArabicNews': ['nio    puttqqq    putf    putvrm    put… '],
#  'CarlPHI22278711': ['rt marketrebels nio    puttqqq    putf    putvrm    putbac …'],
#  'MarketRebels': ['nio    puttqqq    putf    putvrm    put… '],
#  'GailHedglin': ['downtown wow chpt are you kidding its losing  no pe shorted  negative cash flow and operating cash  couldnt be any worse lol'],
#  'keithster1': ['wallstreetbets reddit robinhoodapp ibkr thinkorswim tastyworks halftimereport josh downtown recommends again chpt as final trade'],
#  'AZTraderJim': ['chpt one to keep an eye on here nice weekly reversal candle last week amp good tail again this week butting up aga… '],
#  'RareSterling': [' election campaign camels chpt tsla blnk spwrdo your earnings transcript  alternative energy incentives… '],
#  'JMTradezxcii': ['not an investor but its ridiculous the price of chpt wbx evgo then look at allg  only ebita positive and… '],
#  'StockswithLenny': ['chptabout to retest the downward trendline again look how many times it got rejected here can it break this ti… '],
#  'stennypocksman': ['blnk and chpt calls are printing today ready for nxmr to run run run run runnnnn'],
#  'droneview360': ['chpt   '],
#  'AriesFlow': ['chpt   calltype largetime total size  contractstotal value average pr… '],
#  'Options_Experts': ['chpt  best business model ever  us govt pays u to install ev charging stations everywhere you reap the quarterl… '],
#  'CeoPurchases': ['inverse crameramat  opinionbuyamn  opinionbuybaba  opinionsellbros da… '],
#  'stadestrades': ['wl  spy qqq chpt intc '],
#  'MaiteMerenda': ['chpt awaiting for short signal support and resistance from  to  free trial at … '],
#  'OpinicusHolding': ['top increases in open interest kr   put bbd   call  chpt   call dvn   call… '],
#  'Jarvis_Alerts': ['chpt   ↑↑   totalday unusualactivitysignup free for beta ver… '],
#  'damienj410': ['rt upboptionmil todays top stock option open interest changes f sofi kr dkng agnc clvs pcg fsk chpt pins dis intc '],
#  'i_sentiment': ['idex ok  chpt blnk muln evgo  '],
#  'RGB_NFTs_': ['rt betterscript of the turkey really yeah so youre next thing you know im in mexicosweet kitty dag kava chpt nft'],
#  'ev_advocate': ['spacpicks like plby dumped on ticker change like qs dumped on ticker change or chpt they have no clue'],
#  'TheBetterBull': ['lenraleigh definitely agree though jb likes being private so right now sticking with licy alongside lac then charging chpt '],
#  'paynej247': ['rt upboptionmil todays top stock option open interest changes f sofi kr dkng agnc clvs pcg fsk chpt pins dis intc '],
#  'foty2015': ['tradytics chpt boom   done '],
#  'SweepCastApp': ['sweepcast  unusual options observed  chpt with our scanner on  call expiring  worth   start yo… '],
#  'Snakecase_': ['chpt from zarickman '],
#  'zarickman': ['snakecase chpt '],
#  'BullishCesar100': ['mrmikeinvesting youre not into chpt '],
#  'TraderJike': ['chpt chart suggesting a possible move down to  '],
#  'HellCatTrader': ['still holding puts  aapl pltr amd chpt ']}

# %%
data_df = pd.DataFrame.from_dict(data_clean_new).transpose()
data_df.columns = ['tweets']
data_df
# Out:
#                                                             tweets
# hunter62046908                chpt top analyst price target today
# Gambiste1             rt isentiment idex ok  chpt blnk muln evgo
# GinoDeLaRose     ◦letsgo spy amc gme muln hymc bbig rdbx  sndl ...
# EssaronyMoha                                                chpt
# shortvolumes      short sale volume not short interest for chpt...
# ...                                                            ...
# Snakecase_                                    chpt from zarickman
# zarickman                                          snakecase chpt
# BullishCesar100               mrmikeinvesting youre not into chpt
# TraderJike         chpt chart suggesting a possible move down to
# HellCatTrader              still holding puts  aapl pltr amd chpt
#
# [107 rows x 1 columns]

# %%
data_df.to_pickle('clean_corpus.pkl')
