# %%
import sys, os, pickle
import tweepy as tw
import pandas as pd

# %%
def twitter_auth():
    try:
        consumer_key = os.environ['TWITTER_API_KEY']
        consumer_secret = os.environ['TWITTER_API_SECRET']
        access_token = os.environ['TWITTER_API_ACCESS_TOKEN']
        access_secret=os.environ['TWITTER_API_ACCESS_TOKEN_SECRET']
    except KeyError:
        sys.stderr.write("Environment variable not set\n")
        sys.exit(1)
    
    auth = tw.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    
    return auth

# %%
def get_twitter_client():
    auth = twitter_auth()
    client = tw.API(auth, wait_on_rate_limit=True)
    return client

# %%
# Gather the data

# %%
search_terms = "#FED" + " -filter:retweets"
date_since = '2022-06-21'

# %%
client = get_twitter_client()
tweets = tw.Cursor(client.search_tweets, q=search_terms, lang='en', since=date_since).items(100)
saved_tweets = {}

for tweet in tweets:
    saved_tweets[tweet.user.screen_name] = tweet.text

# for tweet in tweets:
#     saved_tweets.append(tweet.text)
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since
# Unexpected parameter: since

# %%
for user, tweet in saved_tweets.items():
    print(user + "->" + tweet)
    
    
# print(saved_tweets)
# Out:
# KitcoNewsNOW->#Powell on #China: I don’t expect we’ve seen the full effects of China lockdowns … As long as the zero-COVID policy… https://t.co/uX6szCxHPH

# %%
#pickle tweets for later use instead of hitting the API all the time

with open('FED/tweets.txt', 'wb') as file:
    pickle.dump(saved_tweets, file)

# %%
# read from file
with open('FED/tweets.txt', 'rb') as file:
    data = pickle.load(file)

# %%
data
# Out:
# {'KitcoNewsNOW': '#Powell on #China: I don’t expect we’ve seen the full effects of China lockdowns … As long as the zero-COVID policy… https://t.co/uX6szCxHPH',
#  'xglobalmarkets': 'EFFECTIVE FED FUNDS RATE 1.58% JUNE 21 VS 1.58% JUNE 17.\n#XGlobalMarkets #rates #inflation #Fed #economy',
#  'KVanderschrick': "#Fed's Powell - There's some evidence of wages flattening out:: We are seeing a slowing in housing.Rate rises shoul… https://t.co/M6PUalKako",
#  'pleasantville73': '@financialjuice ‘We don’t think” operative words and probably literal! #FED',
#  'aLtErNaTePeTeR': "#pOwElL ReFuSeD To aNsWeR A QuEsTiOn fRoM A SeNaToR As tO WhAt #CoNgReSs cAn dO To mAkE ThE #fEd's jOb oF FiGhTiNg… https://t.co/VVukpGqSiI",
#  'VanessaBrownTV': 'My non-expert take on #Powell’s #Fed plan— \n1. Wreck the economy… to fix the economy \n2. Help people lose $ (stocks… https://t.co/mUlqzv3E6W',
#  'RealMMOShow': 'Cortez Masto (D): \n\nQ: What can you do about oil companies driving up prices while making record profits? \n\nA: That… https://t.co/zy3ci9pUrh',
#  'GregDaco': '#Fed Chair #Powell Semiannual Monetary Policy Report to Congress:\n\n1⃣ Understand hardship high #inflation is causin… https://t.co/bx5pJRAV64',
#  '_all_fintech': '#recession #FED $SPY $BAC $SPX The only way to lower inflation is to kill employment and the economy growth. https://t.co/0hIYibWSRB',
#  'KanzenZasi': '10y #yields fall 14 points as people believe lawyer who tell them he is not doing what he is doing\n\n#fed #markets https://t.co/yl056EE66H',
#  'EconomicsRisk': 'With high #inflation shattering consumer and investor confidence, forecast probabilities are leaning closer to rece… https://t.co/v4w52RSEMf',
#  'themacrotweet': 'US #payrolls: All employees, utilities, seasonally adjusted\n#Fed #fomc #economy #fintwit #economics #finance #forex… https://t.co/Qo9tsK0IBo',
#  'TheNobleRetard': 'I smell a pivot....\n#markets\n#equities\n#Fed\n#FederalReserve\nhttps://t.co/r3b8lGsvb0',
#  'l_malen': "#FED's speakers this week \n - J.Powell testifies at the Senate banking committee\n ( Wednesday)  today and at the Ho… https://t.co/rg1CSCLrYu",
#  'wallstmaster': '"inflation was high, certainly before the war in #Ukraine broke out" - Jerome Powell\n\n#Fed #federalreserve',
#  'PeterSchiff': '#Powell said he is not at all concerned about the #Fed realizing huge balance sheet losses when it sell assets, cur… https://t.co/b0fagnd8jT',
#  'jackcuerton': '#Fed: Rate Rises could lead to a possible #Recession.',
#  'MoodixMarket': '🟢️ #FED | Strength of news 0.1150b\n\nToday #sentiment: 🟢 Positive 0.442\nWeek #sentiment: 🔴 Negative -0.03\n\nLong-term… https://t.co/pk3gcaxcdl',
#  'j_que_': 'I bet this #Senate meeting room smells like an old medicine cabinet #Fed',
#  'UnEspeculador': 'if prices don’t go up , then inflation goes to zero \nJay Powell \n#Fed',
#  'Go_CIO': 'Does anyone want to start talking about the skills gap yet? #Fed',
#  'forexanalytix': "#Fed's Powell - There's some evidence of wages flattening out:\n$USD",
#  'JessieLivermore': 'Well then, that’s that - nothing to worry about folks  #Fed https://t.co/qOFGpmLrQV',
#  'vinniepalma': 'Again, a pop in crude 4 hour following Powell comments, makes for "false hope" in equity &amp; other risk assets.🥳🤡😂🤨… https://t.co/L8NuuYFunr',
#  'litaruby': "Is It just me or Is there just a little too much godliness given to the #Fed ? They can't even opinionate on anythi… https://t.co/8IxgUJhgER",
#  'HakimiMahalil': '@nomadrevelation @GameofTrades_ Recently, the #FED tapered #QE on November 2021\nEnded #QE on March 2022\nBegan #QT o… https://t.co/kLYc9Zagy5',
#  'charuchandna': 'Powell - recession is a possibility but not our intent … \n\n#Fed https://t.co/azwS78at0s',
#  'markets_ya': "Check out the today's US Session commodities and their price action with trading strategies:… https://t.co/Le6BihCWLG",
#  'alpepinnazzo': 'BoA:  🕵️\u200d♂️Card spending by groups\n\n#economy #powell #fed #inflation #markets $SPX $BAC $V $MA $AXP $GS $XLF https://t.co/TiYeS4ou3V',
#  'FXStreetNews': 'Powell speech: Focused on part of inflation we can address By @eren_fxstreet https://t.co/Yq0Y8l6ATN #Fed #CentralBanks',
#  'MBjegovic': 'I expect we will reach the peak rate of 2% or 2.25% in July before the #Fed pivots and cuts in September.\n\n#economy… https://t.co/cMfsmh2AP1',
#  'SunAndStormInv': '$SPX $SPY $IJH $IWM  $QQQ  The #Fed is deliberately slowing the US economy to control #inflation in case you had an… https://t.co/mtAMTgS8J4',
#  'PeterSm16087569': 'It is obvious from today’s Fed hearing that the Senate does not understand history or economics. #senate #fed #economics #inflation',
#  'JEREMYSONG750': '“The #Fed has a very, very #blunttool — they #influence #financial conditions primarily through short-term interest… https://t.co/wORSrwlLFy',
#  'cappuccinobus': 'Feel bad for Powell as they ask him again and again comments on fiscal policy 😂 \n\n#powell #fed #economy',
#  'Geopolitix3': '#Fed and #Treasury stimulus threw fuel on the fire of #US #inflation \nhttps://t.co/S4F0wZpbsd',
#  'CurrencyGuy': 'Powell: price stability is really the bedrock of the economy... we must, must restore price stability.  And we will.  #Fed',
#  'BlackOutWhale': 'Kennedy absolutly grilled Powell\nDUH! \n#FED # Cryptocrash #3AC',
#  '_romilkapoor_': "@sidd1307 It's a pity #Fed cannot print Gas and Fuel",
#  'ReddySalina': '#Fed #POWELL: THE MOST RECENT #inflation  #INDICATORS SUGGESTED WE NEEDED TO #ACCELERATE PACE OF #RATE HIKES.… https://t.co/LDQBJ6as3O',
#  'KenR0415': 'Coughing up bones?  Huh?  #Fed #powell',
#  'durezzadelviver': 'Slow down growth. #FED #Inflation #Powell https://t.co/7FjBZFCf40',
#  'askslim': '#Powell testimony \n\nIt’s incredibly mind-boggling , if you’re watching the testimony, all of the comments from the… https://t.co/ZBtiUYrdP0',
#  'shreyyy30': 'No one knows what tools does powell has to control inflation , its one of the  mysteries around the world 😐\n#Fed… https://t.co/0Wsbg7wX4c',
#  'RosannaTrades': 'Powell Sees Ongoing Fed Rate Hikes Needed to Tame Hot Inflation\n• #Fed admitted they were too slow to tighten &amp; are… https://t.co/dnY63SM1Gr',
#  'yellowdijon': "Why do they keep inviting Powell to these public hearings? I'd love to see people on the budget and finance committ… https://t.co/HvLhQjCH8a",
#  'Mrs__finance': '#Powell said #Fed will be looking for compelling evidence that #inflation is moving down over coming months but rep… https://t.co/wz2DnCAWEv',
#  'DennisKelleher': '.@federalreserve Chair Powell asked @SenateBanking hearing about Basel Committee lowering capital for European GSIB… https://t.co/iChjtpwh36',
#  'UpshotSleuth': 'The White House endorses a House bill that would require the Federal Reserve to include racial equity in making mon… https://t.co/sbkMdWuOYi',
#  'Sino_Market': "POWELL: WE NEED RESTRICTIVE POLICY, THAT'S WHERE WE'RE HEADED. NOT FED'S JUDGMENT TO MAKE ON OIL INDUSTRY COMPETITI… https://t.co/Ybije1TLul",
#  'sidd1307': 'The FED fund rate is only at 1.75%. There is some way to go for rate increases. \n\nIt won’t happen overnight but lik… https://t.co/8VOIPt3WnO',
#  'itsarafat': 'Chairman on #inflation: we are focused on the part of inflation that we can control — demand\n#Fed',
#  'masked_investor': "Someone told Jerome Powell that he might now be doing his job? Inflation wasn't transitory?\noh my, oh my.… https://t.co/1ExeAh7jo8",
#  'annagolubova': '#Bitcoin price as #Fed’s #Powell testifies before the U.S. Senate Banking Committee https://t.co/giJv3NPHUc',
#  'astuteassets1': "#Bitcoin price rises to $20.7K as #Fed's Powell says more rate hikes 'appropriate' https://t.co/JrsnPPLJmr via @cointelegraph",
#  'x2da4': '#Powell testimony summary:\n\nSenators hoping to pin their thoughtless policy mistakes on the #Fed \n\n“We suck. So you’re our fall guy”',
#  'chartsniping': '#Powell and #Congress talking about #Oil prices leading #inflation and how the #FED is taking that into account.\n\nN… https://t.co/dH3CmDghEC',
#  'sumitkapoor16': 'Fed Chair Jerome Powell says the "Central bank will keep raising interest rates to tame inflation."\n\n#Fed #Powell #Inflation #Interestrates',
#  'PSuiteNetwork': "Rate Hikes Don't Make Baby Formula\nRate Hikes Don't Make Fertilizer\nRate Hikes Don't Lower Gas Prices\nRate Hikes Do… https://t.co/KuaFlRj3Kh",
#  'realLisaDaly': "Jerome Powell is getting grilled by the Senate Banking Committee. The Senator from Nevada was trying to put 'a soun… https://t.co/K4ofwGejgG",
#  'mckonomy': "What is it about people on Capitol Hill that they don't understand the difference between oil prices and gasoline p… https://t.co/q3FecQ1nMh",
#  'soldatthetop': '@jeannasmialek Totally false. The #Fed is right now in the process of brewing a notable #recession which will work… https://t.co/n18IxjBFnK',
#  'thakre_aarya': '@PeterSchiff The #Fed has a history of operating in secrecy.  Why is the senator getting into that territory althou… https://t.co/3sozk9ZFTe',
#  'sohaibeth': 'THE FED &amp; Russians are panicking you to sell your holdings. Your stocks &amp; Crypto so they can buy more. "Buy when th… https://t.co/LalJaNH1NK',
#  'authenticchad': 'Fed Money Printer 🖨💵💵💵💵 #Bitcoin #FederalReserve #fed #fiatmoney https://t.co/j5wyhjvb9c'}

# %%
len(data)
# Out:
# 65

# %%
# Clean Data

# %%
# Convert list to one gigantic string

# def combine_tweets(list_of_tweets):
#     combined_tweet = ''.join(list_of_tweets)
#     return combined_tweet

# %%
# data_combined =  combine_tweets(data)

# %%
# data_combined
# Out:
# '@SeedifyFund @MNZToken #Powell #BNB #Fed #Bitcoin #Binance #BTC Lets go MNZToken 🤑🤑🤑🚀🚀🚀🚀 1000x🚀🚀🚀@SquawkStreet July Scholarship, get a new Mac Pro? #cnbc #Fed Like it or not.She belongs in a hospital\n@SenWarren #FederalReserve #fed #inflation https://t.co/c281q0JmKk🇺🇸 FED\'s Powell:\n\nFinancial conditions have tightened significantly, reflecting both actions taken so far and actio… https://t.co/ROL9hDIuAO🇺🇸 FED\'s Powell:\n\nFinancial conditions have tightened significantly, reflecting both actions taken so far and actio… https://t.co/nlVVNrWg1kThom Tillis (R) opening statements: \n\n\'Morgan Stanley blames inflation on excess government spending.\' \n\n\'Monetary… https://t.co/bF1lWhgjV5Dear God, @SenWarren is a moron. #FedThe Fed: “Everything’s good. Everything’s fine. What’s not fine is Putin’s fault.” \n\n🤦🏻\u200d♂️ #election2022 #Fed #Bidenflation #economy🇺🇸 FED\'s Powell:\n\nThe Fed will continue to communicate its thinking as clearly as possible.\n\n#eurusd #dollar #fed https://t.co/8jTfaeYZUz🇺🇸 FED\'s Powell:\n\nThe Fed will continue to communicate its thinking as clearly as possible.\n\n#eurusd #dollar #fed https://t.co/hWE0Vi0f6I#POWELL: We are highly attentive to #inflation risks and determined to take the measures necessary to restore price… https://t.co/9zK7EfUN60#POWELL: The #economy often evolves in unexpected ways. #Inflation has obviously surprised to the upside over the p… https://t.co/31YVmDiwiQ#FED\'S POWELL: GROWTH IN BUSINESS FIXED INVESTMENT APPEARS TO BE SLOWING, AND THE HOUSING SECTOR APPEARS TO BE SOFT… https://t.co/pOD91k60vT#POWELL: Financial conditions have been tightening since last fall and have now tightened significantly, reflecting… https://t.co/ipAvoKR4LH🇺🇸 The #Fed forecasts tend to be overly optimistic and they have the likelihood of a #recession at 50%.\n https://t.co/oRv27xgFGv#FED\'S POWELL: THE PACE OF FUTURE RATE INCREASES WILL CONTINUE TO RELY ON INCOMING DATA AND EVOLVING ECONOMIC OUTLO… https://t.co/tYcdM4EBc4@business @stacyherbert The #Fed worked so hard to #relfate the economy post-2008/09 financial crisis that ultimate… https://t.co/0MAHSIJlsg🇺🇸 Powell Sees Ongoing #Fed Rate Hikes Needed to Tame Hot Inflation - Bloomberg\nhttps://t.co/iqsY2r6jWc#FED\'S POWELL: WE WILL MAKE OUR DECISIONS MEETING BY MEETING.\n\nFED\'S #POWELL: IT IS CRITICAL THAT INFLATION BE BROU… https://t.co/KkjsO1bkFR@DeItaone His function is to not telegraph... So essentially the #Fed lies... comments are meaningless#FED\'S POWELL: LABOR DEMAND IS VERY STRONG, WHILE LABOR SUPPLY REMAINS SUBDUED, WITH THE LABOR FORCE PARTICIPATION… https://t.co/WdB00fFHBA#FED\'S POWELL: FINANCIAL CONDITIONS HAVE TIGHTENED SIGNIFICANTLY, REFLECTING BOTH ACTIONS TAKEN SO FAR AND ACTIONS… https://t.co/rXqRQFcIae#Fed  Chair Powell: #US economy is very strong and it can handle tighter policy#FED\'S POWELL: INFLATION HAS OBVIOUSLY SURPRISED TO THE UPSIDE AND FURTHER SURPRISES COULD BE IN STORE; FED WILL NE… https://t.co/MjFuUy1w79"We aren\'t seeing traditional inflation. We\'re seeing Russia and OPEC drive prices and American energy  companies e… https://t.co/EXtoaWUXezFed Chair J. Powell testimony live thread: \n\n"There is no invisible hand of the market. When prices go up, it\'s bec… https://t.co/GwLaBthqda#POWELL: We are strongly committed to bringing inflation back down, and we are moving expeditiously to do so.  #FEDContent analysis:\nThis article scores 87/100. The complete report can be viewed here: https://t.co/VSSAFXYE0Y\n(I\'m… https://t.co/r8qcgGvSUh#Powell stressed that the #Fed is strongly committed to returning #inflation to 2%.\n\n#monetaryPolicy #interestrates… https://t.co/3rbZJXgLi5US Federal Reserve Chairman Jerome Powell told congressional lawmakers that the US central bank is determined to br… https://t.co/rp5ukCcmgmFED\'S HARKER: IF NEED TO DECELERATE, ACCELERATE ECONOMY, WE DO THAT THROUGH FED FUNDS RATE.\n\nFED\'S HARKER: THERE AR… https://t.co/ZlUCkuSXDE#FED paylasti: Chair Powell presents the Monetary P ...

# %%
# Apply first round of data cleaning

import re
import string

def clean_text_round1(text):
    '''Make text lowercase and remove punctuation'''
    text = text.lower()
    text = re.sub('\[.*?\]','', text)
    text = re.sub('["%s"]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(r'http\S+', '', text)
    
    return text

# round1 = lambda x: clean_text_round1(x)

data_clean_1 = {}

for user, tweet in data.items():
    data_clean_1[user] = clean_text_round1(tweet)

# %%
data_clean_1
# Out:
# {'KitcoNewsNOW': 'powell on china i don’t expect we’ve seen the full effects of china lockdowns … as long as the zerocovid policy… ',
#  'xglobalmarkets': 'effective fed funds rate  june  vs  june \nxglobalmarkets rates inflation fed economy',
#  'KVanderschrick': 'feds powell  theres some evidence of wages flattening out we are seeing a slowing in housingrate rises shoul… ',
#  'pleasantville73': 'financialjuice ‘we don’t think” operative words and probably literal fed',
#  'aLtErNaTePeTeR': 'powell refused to answer a question from a senator as to what congress can do to make the feds job of fighting… ',
#  'VanessaBrownTV': 'my nonexpert take on powell’s fed plan— \n wreck the economy… to fix the economy \n help people lose  stocks… ',
#  'RealMMOShow': 'cortez masto d \n\nq what can you do about oil companies driving up prices while making record profits \n\na that… ',
#  'GregDaco': 'fed chair powell semiannual monetary policy report to congress\n\n⃣ understand hardship high inflation is causin… ',
#  '_all_fintech': 'recession fed spy bac spx the only way to lower inflation is to kill employment and the economy growth ',
#  'KanzenZasi': ' yields fall  points as people believe lawyer who tell them he is not doing what he is doing\n\nfed markets ',
#  'EconomicsRisk': 'with high inflation shattering consumer and investor confidence forecast probabilities are leaning closer to rece… ',
#  'themacrotweet': 'us payrolls all employees utilities seasonally adjusted\nfed fomc economy fintwit economics finance forex… ',
#  'TheNobleRetard': 'i smell a pivot\nmarkets\nequities\nfed\nfederalreserve\n',
#  'l_malen': 'feds speakers this week \n  jpowell testifies at the senate banking committee\n  wednesday  today and at the ho… ',
#  'wallstmaster': 'inflation was high certainly before the war in ukraine broke out  jerome powell\n\nfed federalreserve',
#  'PeterSchiff': 'powell said he is not at all concerned about the fed realizing huge balance sheet losses when it sell assets cur… ',
#  'jackcuerton': 'fed rate rises could lead to a possible recession',
#  'MoodixMarket': '🟢️ fed  strength of news \n\ntoday sentiment 🟢 positive \nweek sentiment 🔴 negative \n\nlongterm… ',
#  'j_que_': 'i bet this senate meeting room smells like an old medicine cabinet fed',
#  'UnEspeculador': 'if prices don’t go up  then inflation goes to zero \njay powell \nfed',
#  'Go_CIO': 'does anyone want to start talking about the skills gap yet fed',
#  'forexanalytix': 'feds powell  theres some evidence of wages flattening out\nusd',
#  'JessieLivermore': 'well then that’s that  nothing to worry about folks  fed ',
#  'vinniepalma': 'again a pop in crude  hour following powell comments makes for false hope in equity amp other risk assets🥳🤡😂🤨… ',
#  'litaruby': 'is it just me or is there just a little too much godliness given to the fed  they cant even opinionate on anythi… ',
#  'HakimiMahalil': 'nomadrevelation gameoftrades recently the fed tapered qe on november \nended qe on march \nbegan qt o… ',
#  'charuchandna': 'powell  recession is a possibility but not our intent … \n\nfed ',
#  'markets_ya': 'check out the todays us session commodities and their price action with trading strategies… ',
#  'alpepinnazzo': 'boa  🕵️\u200d♂️card spending by groups\n\neconomy powell fed inflation markets spx bac v ma axp gs xlf ',
#  'FXStreetNews': 'powell speech focused on part of inflation we can address by erenfxstreet  fed centralbanks',
#  'MBjegovic': 'i expect we will reach the peak rate of  or  in july before the fed pivots and cuts in september\n\neconomy… ',
#  'SunAndStormInv': 'spx spy ijh iwm  qqq  the fed is deliberately slowing the us economy to control inflation in case you had an… ',
#  'PeterSm16087569': 'it is obvious from today’s fed hearing that the senate does not understand history or economics senate fed economics inflation',
#  'JEREMYSONG750': '“the fed has a very very blunttool — they influence financial conditions primarily through shortterm interest… ',
#  'cappuccinobus': 'feel bad for powell as they ask him again and again comments on fiscal policy 😂 \n\npowell fed economy',
#  'Geopolitix3': 'fed and treasury stimulus threw fuel on the fire of us inflation \n',
#  'CurrencyGuy': 'powell price stability is really the bedrock of the economy we must must restore price stability  and we will  fed',
#  'BlackOutWhale': 'kennedy absolutly grilled powell\nduh \nfed  cryptocrash ',
#  '_romilkapoor_': ' its a pity fed cannot print gas and fuel',
#  'ReddySalina': 'fed powell the most recent inflation  indicators suggested we needed to accelerate pace of rate hikes… ',
#  'KenR0415': 'coughing up bones  huh  fed powell',
#  'durezzadelviver': 'slow down growth fed inflation powell ',
#  'askslim': 'powell testimony \n\nit’s incredibly mindboggling  if you’re watching the testimony all of the comments from the… ',
#  'shreyyy30': 'no one knows what tools does powell has to control inflation  its one of the  mysteries around the world 😐\nfed… ',
#  'RosannaTrades': 'powell sees ongoing fed rate hikes needed to tame hot inflation\n• fed admitted they were too slow to tighten amp are… ',
#  'yellowdijon': 'why do they keep inviting powell to these public hearings id love to see people on the budget and finance committ… ',
#  'Mrs__finance': 'powell said fed will be looking for compelling evidence that inflation is moving down over coming months but rep… ',
#  'DennisKelleher': 'federalreserve chair powell asked senatebanking hearing about basel committee lowering capital for european gsib… ',
#  'UpshotSleuth': 'the white house endorses a house bill that would require the federal reserve to include racial equity in making mon… ',
#  'Sino_Market': 'powell we need restrictive policy thats where were headed not feds judgment to make on oil industry competiti… ',
#  'sidd1307': 'the fed fund rate is only at  there is some way to go for rate increases \n\nit won’t happen overnight but lik… ',
#  'itsarafat': 'chairman on inflation we are focused on the part of inflation that we can control — demand\nfed',
#  'masked_investor': 'someone told jerome powell that he might now be doing his job inflation wasnt transitory\noh my oh my… ',
#  'annagolubova': 'bitcoin price as fed’s powell testifies before the us senate banking committee ',
#  'astuteassets1': 'bitcoin price rises to  as feds powell says more rate hikes appropriate  via cointelegraph',
#  'x2da4': 'powell testimony summary\n\nsenators hoping to pin their thoughtless policy mistakes on the fed \n\n“we suck so you’re our fall guy”',
#  'chartsniping': 'powell and congress talking about oil prices leading inflation and how the fed is taking that into account\n\nn… ',
#  'sumitkapoor16': 'fed chair jerome powell says the central bank will keep raising interest rates to tame inflation\n\nfed powell inflation interestrates',
#  'PSuiteNetwork': 'rate hikes dont make baby formula\nrate hikes dont make fertilizer\nrate hikes dont lower gas prices\nrate hikes do… ',
#  'realLisaDaly': 'jerome powell is getting grilled by the senate banking committee the senator from nevada was trying to put a soun… ',
#  'mckonomy': 'what is it about people on capitol hill that they dont understand the difference between oil prices and gasoline p… ',
#  'soldatthetop': 'jeannasmialek totally false the fed is right now in the process of brewing a notable recession which will work… ',
#  'thakre_aarya': 'peterschiff the fed has a history of operating in secrecy  why is the senator getting into that territory althou… ',
#  'sohaibeth': 'the fed amp russians are panicking you to sell your holdings your stocks amp crypto so they can buy more buy when th… ',
#  'authenticchad': 'fed money printer 🖨💵💵💵💵 bitcoin federalreserve fed fiatmoney '}

# %%
# Apply round 2 of data cleaning
import emoji

def clean_text_round2(text):
    
    text = emoji.get_emoji_regexp().sub(r'', text)
    text = text.replace("\n", "")
    
    return text

data_clean = {}

for user, tweet in data_clean_1.items():
    data_clean[user] = [clean_text_round2(tweet)]
    
data_clean
# Out:
# /var/folders/ly/b0d5ymx54rd755r8d506sd000000gn/T/ipykernel_31397/1311328516.py:6: DeprecationWarning: 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'
#   text = emoji.get_emoji_regexp().sub(r'', text)
# {'KitcoNewsNOW': ['powell on china i don’t expect we’ve seen the full effects of china lockdowns … as long as the zerocovid policy… '],
#  'xglobalmarkets': ['effective fed funds rate  june  vs  june xglobalmarkets rates inflation fed economy'],
#  'KVanderschrick': ['feds powell  theres some evidence of wages flattening out we are seeing a slowing in housingrate rises shoul… '],
#  'pleasantville73': ['financialjuice ‘we don’t think” operative words and probably literal fed'],
#  'aLtErNaTePeTeR': ['powell refused to answer a question from a senator as to what congress can do to make the feds job of fighting… '],
#  'VanessaBrownTV': ['my nonexpert take on powell’s fed plan—  wreck the economy… to fix the economy  help people lose  stocks… '],
#  'RealMMOShow': ['cortez masto d q what can you do about oil companies driving up prices while making record profits a that… '],
#  'GregDaco': ['fed chair powell semiannual monetary policy report to congress⃣ understand hardship high inflation is causin… '],
#  '_all_fintech': ['recession fed spy bac spx the only way to lower inflation is to kill employment and the economy growth '],
#  'KanzenZasi': [' yields fall  points as people believe lawyer who tell them he is not doing what he is doingfed markets '],
#  'EconomicsRisk': ['with high inflation shattering consumer and investor confidence forecast probabilities are leaning closer to rece… '],
#  'themacrotweet': ['us payrolls all employees utilities seasonally adjustedfed fomc economy fintwit economics finance forex… '],
#  'TheNobleRetard': ['i smell a pivotmarketsequitiesfedfederalreserve'],
#  'l_malen': ['feds speakers this week   jpowell testifies at the senate banking committee  wednesday  today and at the ho… '],
#  'wallstmaster': ['inflation was high certainly before the war in ukraine broke out  jerome powellfed federalreserve'],
#  'PeterSchiff': ['powell said he is not at all concerned about the fed realizing huge balance sheet losses when it sell assets cur… '],
#  'jackcuerton': ['fed rate rises could lead to a possible recession'],
#  'MoodixMarket': ['️ fed  strength of news today sentiment  positive week sentiment  negative longterm… '],
#  'j_que_': ['i bet this senate meeting room smells like an old medicine cabinet fed'],
#  'UnEspeculador': ['if prices don’t go up  then inflation goes to zero jay powell fed'],
#  'Go_CIO': ['does anyone want to start talking about the skills gap yet fed'],
#  'forexanalytix': ['feds powell  theres some evidence of wages flattening outusd'],
#  'JessieLivermore': ['well then that’s that  nothing to worry about folks  fed '],
#  'vinniepalma': ['again a pop in crude  hour following powell comments makes for false hope in equity amp other risk assets… '],
#  'litaruby': ['is it just me or is there just a little too much godliness given to the fed  they cant even opinionate on anythi… '],
#  'HakimiMahalil': ['nomadrevelation gameoftrades recently the fed tapered qe on november ended qe on march began qt o… '],
#  'charuchandna': ['powell  recession is a possibility but not our intent … fed '],
#  'markets_ya': ['check out the todays us session commodities and their price action with trading strategies… '],
#  'alpepinnazzo': ['boa  card spending by groupseconomy powell fed inflation markets spx bac v ma axp gs xlf '],
#  'FXStreetNews': ['powell speech focused on part of inflation we can address by erenfxstreet  fed centralbanks'],
#  'MBjegovic': ['i expect we will reach the peak rate of  or  in july before the fed pivots and cuts in septembereconomy… '],
#  'SunAndStormInv': ['spx spy ijh iwm  qqq  the fed is deliberately slowing the us economy to control inflation in case you had an… '],
#  'PeterSm16087569': ['it is obvious from today’s fed hearing that the senate does not understand history or economics senate fed economics inflation'],
#  'JEREMYSONG750': ['“the fed has a very very blunttool — they influence financial conditions primarily through shortterm interest… '],
#  'cappuccinobus': ['feel bad for powell as they ask him again and again comments on fiscal policy  powell fed economy'],
#  'Geopolitix3': ['fed and treasury stimulus threw fuel on the fire of us inflation '],
#  'CurrencyGuy': ['powell price stability is really the bedrock of the economy we must must restore price stability  and we will  fed'],
#  'BlackOutWhale': ['kennedy absolutly grilled powellduh fed  cryptocrash '],
#  '_romilkapoor_': [' its a pity fed cannot print gas and fuel'],
#  'ReddySalina': ['fed powell the most recent inflation  indicators suggested we needed to accelerate pace of rate hikes… '],
#  'KenR0415': ['coughing up bones  huh  fed powell'],
#  'durezzadelviver': ['slow down growth fed inflation powell '],
#  'askslim': ['powell testimony it’s incredibly mindboggling  if you’re watching the testimony all of the comments from the… '],
#  'shreyyy30': ['no one knows what tools does powell has to control inflation  its one of the  mysteries around the world fed… '],
#  'RosannaTrades': ['powell sees ongoing fed rate hikes needed to tame hot inflation• fed admitted they were too slow to tighten amp are… '],
#  'yellowdijon': ['why do they keep inviting powell to these public hearings id love to see people on the budget and finance committ… '],
#  'Mrs__finance': ['powell said fed will be looking for compelling evidence that inflation is moving down over coming months but rep… '],
#  'DennisKelleher': ['federalreserve chair powell asked senatebanking hearing about basel committee lowering capital for european gsib… '],
#  'UpshotSleuth': ['the white house endorses a house bill that would require the federal reserve to include racial equity in making mon… '],
#  'Sino_Market': ['powell we need restrictive policy thats where were headed not feds judgment to make on oil industry competiti… '],
#  'sidd1307': ['the fed fund rate is only at  there is some way to go for rate increases it won’t happen overnight but lik… '],
#  'itsarafat': ['chairman on inflation we are focused on the part of inflation that we can control — demandfed'],
#  'masked_investor': ['someone told jerome powell that he might now be doing his job inflation wasnt transitoryoh my oh my… '],
#  'annagolubova': ['bitcoin price as fed’s powell testifies before the us senate banking committee '],
#  'astuteassets1': ['bitcoin price rises to  as feds powell says more rate hikes appropriate  via cointelegraph'],
#  'x2da4': ['powell testimony summarysenators hoping to pin their thoughtless policy mistakes on the fed “we suck so you’re our fall guy”'],
#  'chartsniping': ['powell and congress talking about oil prices leading inflation and how the fed is taking that into accountn… '],
#  'sumitkapoor16': ['fed chair jerome powell says the central bank will keep raising interest rates to tame inflationfed powell inflation interestrates'],
#  'PSuiteNetwork': ['rate hikes dont make baby formularate hikes dont make fertilizerrate hikes dont lower gas pricesrate hikes do… '],
#  'realLisaDaly': ['jerome powell is getting grilled by the senate banking committee the senator from nevada was trying to put a soun… '],
#  'mckonomy': ['what is it about people on capitol hill that they dont understand the difference between oil prices and gasoline p… '],
#  'soldatthetop': ['jeannasmialek totally false the fed is right now in the process of brewing a notable recession which will work… '],
#  'thakre_aarya': ['peterschiff the fed has a history of operating in secrecy  why is the senator getting into that territory althou… '],
#  'sohaibeth': ['the fed amp russians are panicking you to sell your holdings your stocks amp crypto so they can buy more buy when th… '],
#  'authenticchad': ['fed money printer  bitcoin federalreserve fed fiatmoney ']}

# %%
data_df = pd.DataFrame.from_dict(data_clean).transpose()
data_df.columns = ['tweets']
data_df = data_df.sort_index()
data_df # clean raw corpus
# Out:
#                                                            tweets
# BlackOutWhale   kennedy absolutly grilled powellduh fed  crypt...
# CurrencyGuy     powell price stability is really the bedrock o...
# DennisKelleher  federalreserve chair powell asked senatebankin...
# EconomicsRisk   with high inflation shattering consumer and in...
# FXStreetNews    powell speech focused on part of inflation we ...
# ...                                                           ...
# vinniepalma     again a pop in crude  hour following powell co...
# wallstmaster    inflation was high certainly before the war in...
# x2da4           powell testimony summarysenators hoping to pin...
# xglobalmarkets  effective fed funds rate  june  vs  june xglob...
# yellowdijon     why do they keep inviting powell to these publ...
#
# [65 rows x 1 columns]

# %%
data_df.to_pickle('clean_corpus.pkl')

# %%
# Create Document-term matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_df.tweets)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data_df.index
data_dtm
# Out:
# /Users/timal/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                 absolutly  accelerate  accountn  action  address  adjustedfed  \
# BlackOutWhale           1           0         0       0        0            0
# CurrencyGuy             0           0         0       0        0            0
# DennisKelleher          0           0         0       0        0            0
# EconomicsRisk           0           0         0       0        0            0
# FXStreetNews            0           0         0       0        1            0
# ...                   ...         ...       ...     ...      ...          ...
# vinniepalma             0           0         0       0        0            0
# wallstmaster            0           0         0       0        0            0
# x2da4                   0           0         0       0        0            0
# xglobalmarkets          0           0         0       0        0            0
# yellowdijon             0           0         0       0        0            0
#
#                 admitted  althou  amp  answer  ...  words  work  world  worry  \
# BlackOutWhale          0       0    0       0  ...      0     0      0      0
# CurrencyGuy            0       0    0       0  ...      0     0      0      0
# DennisKelleher         0       0    0       0  ...      0     0      0      0
# EconomicsRisk          0       0    0       0  ...      0     0      0      0
# FXStreetNews           0       0    0       0  ...      0     0      0      0
# ...                  ...     ...  ...     ...  ...    ...   ...    ...    ...
# vinniepalma            0       0    1       0  ...      0     0      0      0
# wallstmaster           0       0    0       0  ...      0     0      0      0
# x2da4                  0       0    0       0  ...      0     0      0      0
# xglobalmarkets         0       0    0       0  ...      0     0      0      0
# yellowdijon            0       0    0       0  ...      0     0      0      0
#
#                 wreck  xglobalmarkets  xlf  yields  zero  zerocovid
# BlackOutWhale       0               0    0       0     0          0
# CurrencyGuy         0               0    0       0     0          0
# DennisKelleher      0               0    0       0     0          0
# EconomicsRisk       0               0    0       0     0          0
# FXStreetNews        0               0    0       0     0          0
# ...               ...             ...  ...     ...   ...        ...
# vinniepalma         0               0    0       0     0          0
# wallstmaster        0               0    0       0     0          0
# x2da4               0               0    0       0     0          0
# xglobalmarkets      0               1    0       0     0          0
# yellowdijon         0               0    0       0     0          0
#
# [65 rows x 381 columns]

# %%
data_dtm.to_pickle('FED_dtm.pkl')

# %%
pickle.dump(cv, open('cv_stop.pkl', "wb"))
