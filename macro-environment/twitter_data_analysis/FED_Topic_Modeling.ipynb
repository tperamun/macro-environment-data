# %%
import pandas as pd
import pickle

data = pd.read_pickle('FED_dtm.pkl')
data
# Out:
#                 absolutly  accelerate  accountn  action  address  adjustedfed  \
# BlackOutWhale           1           0         0       0        0            0
# CurrencyGuy             0           0         0       0        0            0
# DennisKelleher          0           0         0       0        0            0
# EconomicsRisk           0           0         0       0        0            0
# FXStreetNews            0           0         0       0        1            0
# ...                   ...         ...       ...     ...      ...          ...
# vinniepalma             0           0         0       0        0            0
# wallstmaster            0           0         0       0        0            0
# x2da4                   0           0         0       0        0            0
# xglobalmarkets          0           0         0       0        0            0
# yellowdijon             0           0         0       0        0            0
#
#                 admitted  althou  amp  answer  ...  words  work  world  worry  \
# BlackOutWhale          0       0    0       0  ...      0     0      0      0
# CurrencyGuy            0       0    0       0  ...      0     0      0      0
# DennisKelleher         0       0    0       0  ...      0     0      0      0
# EconomicsRisk          0       0    0       0  ...      0     0      0      0
# FXStreetNews           0       0    0       0  ...      0     0      0      0
# ...                  ...     ...  ...     ...  ...    ...   ...    ...    ...
# vinniepalma            0       0    1       0  ...      0     0      0      0
# wallstmaster           0       0    0       0  ...      0     0      0      0
# x2da4                  0       0    0       0  ...      0     0      0      0
# xglobalmarkets         0       0    0       0  ...      0     0      0      0
# yellowdijon            0       0    0       0  ...      0     0      0      0
#
#                 wreck  xglobalmarkets  xlf  yields  zero  zerocovid
# BlackOutWhale       0               0    0       0     0          0
# CurrencyGuy         0               0    0       0     0          0
# DennisKelleher      0               0    0       0     0          0
# EconomicsRisk       0               0    0       0     0          0
# FXStreetNews        0               0    0       0     0          0
# ...               ...             ...  ...     ...   ...        ...
# vinniepalma         0               0    0       0     0          0
# wallstmaster        0               0    0       0     0          0
# x2da4               0               0    0       0     0          0
# xglobalmarkets      0               1    0       0     0          0
# yellowdijon         0               0    0       0     0          0
#
# [65 rows x 381 columns]

# %%
from gensim import matutils , models
import scipy.sparse

# %%
tdm = data.transpose()
tdm.head()
# Out:
#             BlackOutWhale  CurrencyGuy  DennisKelleher  EconomicsRisk  \
# absolutly               1            0               0              0
# accelerate              0            0               0              0
# accountn                0            0               0              0
# action                  0            0               0              0
# address                 0            0               0              0
#
#             FXStreetNews  Geopolitix3  Go_CIO  GregDaco  HakimiMahalil  \
# absolutly              0            0       0         0              0
# accelerate             0            0       0         0              0
# accountn               0            0       0         0              0
# action                 0            0       0         0              0
# address                1            0       0         0              0
#
#             JEREMYSONG750  ...  sohaibeth  soldatthetop  sumitkapoor16  \
# absolutly               0  ...          0             0              0
# accelerate              0  ...          0             0              0
# accountn                0  ...          0             0              0
# action                  0  ...          0             0              0
# address                 0  ...          0             0              0
#
#             thakre_aarya  themacrotweet  vinniepalma  wallstmaster  x2da4  \
# absolutly              0              0            0             0      0
# accelerate             0              0            0             0      0
# accountn               0              0            0             0      0
# action                 0              0            0             0      0
# address                0              0            0             0      0
#
#             xglobalmarkets  yellowdijon
# absolutly                0            0
# accelerate               0            0
# accountn                 0            0
# action                   0            0
# address                  0            0
#
# [5 rows x 65 columns]

# %%
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
cv = pickle.load(open("cv_stop.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())

# %%
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=2, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.046*"powell" + 0.039*"fed" + 0.022*"inflation" + 0.015*"rate" + 0.011*"feds" + 0.011*"price" + 0.010*"economy" + 0.009*"recession" + 0.007*"jerome" + 0.007*"committee"'),
#  (1,
#   '0.052*"fed" + 0.022*"inflation" + 0.021*"powell" + 0.009*"senate" + 0.009*"hikes" + 0.009*"dont" + 0.008*"economy" + 0.007*"prices" + 0.007*"policy" + 0.007*"make"')]

# %%
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.030*"powell" + 0.023*"fed" + 0.019*"inflation" + 0.012*"feds" + 0.012*"evidence" + 0.009*"high" + 0.008*"theres" + 0.008*"wages" + 0.008*"flattening" + 0.008*"oil"'),
#  (1,
#   '0.057*"powell" + 0.055*"fed" + 0.030*"inflation" + 0.017*"economy" + 0.015*"rate" + 0.010*"price" + 0.010*"policy" + 0.008*"jerome" + 0.008*"committee" + 0.008*"chair"'),
#  (2,
#   '0.053*"fed" + 0.018*"hikes" + 0.015*"dont" + 0.012*"inflation" + 0.011*"senate" + 0.011*"does" + 0.011*"amp" + 0.011*"recession" + 0.011*"rate" + 0.008*"prices"')]

# %%
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=4, passes=10)
lda.print_topics()
# Out:
# [(0,
#   '0.024*"inflation" + 0.023*"powell" + 0.023*"fed" + 0.012*"control" + 0.012*"people" + 0.012*"price" + 0.012*"amp" + 0.012*"house" + 0.012*"stability" + 0.012*"making"'),
#  (1,
#   '0.064*"fed" + 0.023*"rate" + 0.015*"recession" + 0.014*"inflation" + 0.014*"powell" + 0.010*"committee" + 0.010*"banking" + 0.010*"jerome" + 0.010*"federalreserve" + 0.010*"today"'),
#  (2,
#   '0.047*"powell" + 0.034*"fed" + 0.028*"inflation" + 0.019*"hikes" + 0.013*"dont" + 0.010*"make" + 0.010*"feds" + 0.010*"rate" + 0.010*"policy" + 0.010*"chair"'),
#  (3,
#   '0.059*"fed" + 0.041*"powell" + 0.019*"inflation" + 0.016*"senate" + 0.016*"economy" + 0.012*"price" + 0.008*"prices" + 0.008*"economics" + 0.008*"congress" + 0.008*"don"')]
