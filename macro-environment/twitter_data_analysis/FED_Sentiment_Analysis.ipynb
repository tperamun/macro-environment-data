# %%
import pandas as pd

data = pd.read_pickle('clean_corpus.pkl')
data
# Out:
#                                                            tweets
# BlackOutWhale   kennedy absolutly grilled powellduh fed  crypt...
# CurrencyGuy     powell price stability is really the bedrock o...
# DennisKelleher  federalreserve chair powell asked senatebankin...
# EconomicsRisk   with high inflation shattering consumer and in...
# FXStreetNews    powell speech focused on part of inflation we ...
# ...                                                           ...
# vinniepalma     again a pop in crude  hour following powell co...
# wallstmaster    inflation was high certainly before the war in...
# x2da4           powell testimony summarysenators hoping to pin...
# xglobalmarkets  effective fed funds rate  june  vs  june xglob...
# yellowdijon     why do they keep inviting powell to these publ...
#
# [65 rows x 1 columns]

# %%
from textblob import TextBlob

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data['tweets'].apply(pol)
data['subjectivity'] = data['tweets'].apply(sub)

data
# Out:
#                                                            tweets  polarity  \
# BlackOutWhale   kennedy absolutly grilled powellduh fed  crypt...  0.000000
# CurrencyGuy     powell price stability is really the bedrock o...  0.200000
# DennisKelleher  federalreserve chair powell asked senatebankin...  0.000000
# EconomicsRisk   with high inflation shattering consumer and in...  0.160000
# FXStreetNews    powell speech focused on part of inflation we ...  0.000000
# ...                                                           ...       ...
# vinniepalma     again a pop in crude  hour following powell co... -0.306250
# wallstmaster    inflation was high certainly before the war in...  0.187143
# x2da4           powell testimony summarysenators hoping to pin...  0.000000
# xglobalmarkets  effective fed funds rate  june  vs  june xglob...  0.600000
# yellowdijon     why do they keep inviting powell to these publ...  0.250000
#
#                 subjectivity
# ...

# %%
# Plot results

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]

for index, user in enumerate(data.index):
    x = data.polarity.loc[user]
    y = data.subjectivity.loc[user]
    
    plt.scatter(x, y, color='blue')
#     plt.text(x + .001, y + .001, data)
    plt.xlim(-.01, .12)
    

plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<--Negative --------Positive -->', fontsize=15)
plt.ylabel('<--Facts -------- Opinions -->', fontsize=15)

plt.show()
